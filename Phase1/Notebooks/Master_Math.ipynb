# %%
import pandas
pandas.__version__
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
cd /Users/dansari/Documents/GitHub/Identifying-features-to-predict-high-school-assessment-proficiency/Phase1/Data/CCD
# Out:
# /Users/dansari/Documents/GitHub/Identifying-features-to-predict-high-school-assessment-proficiency/Phase1/Data/CCD

# %%
ccd_master = pandas.read_csv("Clean_ccd_master.csv")
ccd_master['NCESSCH'] = ccd_master['NCESSCH'].apply(lambda x: '{0:0>12}'.format(x))
ccd_master.head()
# Out:
#   SCHOOL_YEAR  ST                       SCH_NAME     ST_SCHID       NCESSCH  \
# 0   2017-2018  AL        Albertville High School  AL-101-0020  010000500871
# 1   2017-2018  AL             Asbury High School  AL-048-0030  010000600872
# 2   2017-2018  AL            Douglas High School  AL-048-0100  010000600878
# 3   2017-2018  AL   Kate D Smith DAR High School  AL-048-0140  010000600883
# 4   2017-2018  AL  Brindlee Mountain High School  AL-048-0042  010000601585
#
#     SCHID  SY_STATUS   SCH_TYPE_TEXT  SCH_TYPE LEVEL TITLEI_STATUS  \
# 0  100871          1  Regular School         1  High  SWELIGSWPROG
# 1  100872          1  Regular School         1  High  SWELIGSWPROG
# 2  100878          1  Regular School         1  High  SWELIGSWPROG
# 3  100883          1  Regular School         1  High  SWELIGSWPROG
# 4  101585          1  Regular School         1  High  SWELIGSWPROG
#
#           TITLEI_STATUS_TEXT MAGNET_TEXT  TEACHERS  FARMS_COUNT
# 0  Title I schoolwide school          No     77.00        832.0
# 1  Title I schoolwide school          No     28.64        450.0
# 2  Title I schoolwide school          No     30.87        429.0
# 3  Title I schoolwide school          No     24.04        211.0
# 4  Title I schoolwide school          No     31.26        415.0

# %%
ccd_master.shape
# Out:
# (19203, 15)

# %%
cd /Users/dansari/Documents/GitHub/Identifying-features-to-predict-high-school-assessment-proficiency/Phase1/Data/CRDC
# Out:
# /Users/dansari/Documents/GitHub/Identifying-features-to-predict-high-school-assessment-proficiency/Phase1/Data/CRDC

# %%
crdc_master_math = pandas.read_csv("Clean_crdc_master_math.csv")
crdc_master_math['NCESSCH'] = crdc_master_math['NCESSCH'].apply(lambda x: '{0:0>12}'.format(x))
crdc_master_math.head()
# Out:
#   LEA_STATE_x LEA_STATE_NAME_x  LEAID_x        LEA_NAME_x  SCHID_x  \
# 0          AL          ALABAMA   100005  Albertville City      871
# 1          AL          ALABAMA   100006   Marshall County      872
# 2          AL          ALABAMA   100006   Marshall County      878
# 3          AL          ALABAMA   100006   Marshall County      883
# 4          AL          ALABAMA   100006   Marshall County     1585
#
#                       SCH_NAME_x   COMBOKEY_x  Special_ed_schl_new  \
# 0        Albertville High School  10000500871                    0
# 1             Asbury High School  10000600872                    0
# 2            Douglas High School  10000600878                    0
# 3   Kate D Smith DAR High School  10000600883                    0
# 4  Brindlee Mountain High School  10000601585                    0
#
#    Magnet_schl_new  Charter_Schl_new  ...  Total_IB_students  \
# 0                0                 0  ...              -18.0
# 1                0                 0  ...              -18.0
# 2                0                 0  ...              -18.0
# 3                0                 0  ...              -18.0
# 4                0                 0  ...              -18.0
#
#   SCH_APENR_IND_new SCH_APCOURSES  SCH_APMATHENR_IND_new  \
# 0               1.0           8.0                    1.0
# 1               1.0           3.0                    0.0
# 2               1.0           6.0                    1.0
# 3               1.0           6.0                    1.0
# 4               1.0           5.0                    1.0
#
#    Total_AP_math_students  Total_students_tookAP  SCH_MATHCLASSES_ALG  \
# 0                    53.0                  286.0                 23.0
# 1                   -18.0                   46.0                  4.0
# 2                    18.0                  244.0                  4.0
# 3                    18.0                  205.0                  4.0
# 4                    11.0                  102.0                  4.0
#
#    SCH_MATHCERT_ALG  Total_Alg1_enroll_students  Total_Alg1_pass_students
# 0              23.0                       450.0                     428.0
# 1               4.0                        63.0                      62.0
# 2               4.0                       117.0                     113.0
# 3               4.0                       105.0                     105.0
# 4               4.0                       161.0                     149.0
#
# [5 rows x 31 columns]

# %%
crdc_master_math.shape
# Out:
# (16336, 31)

# %%
cd /Users/dansari/Documents/GitHub/Identifying-features-to-predict-high-school-assessment-proficiency/Phase1/Data/EDGE
# Out:
# /Users/dansari/Documents/GitHub/Identifying-features-to-predict-high-school-assessment-proficiency/Phase1/Data/EDGE

# %%
edge = pandas.read_csv("Clean_EDGE.csv")
edge['NCESSCH'] = edge['NCESSCH'].apply(lambda x: '{0:0>12}'.format(x))
edge.head()
# Out:
#         NCESSCH                                 NAME  Income_Poverty_ratio  \
# 0  010000500870            Albertville Middle School                   245
# 1  010000500871              Albertville High School                   248
# 2  010000500879              Evans Elementary School                   174
# 3  010000500889        Albertville Elementary School                   236
# 4  010000501616  Big Spring Lake Kindergarten School                   480
#
#    IPR_SE
# 0      80
# 1      80
# 2      91
# 3     105
# 4     120

# %%
edge.shape
# Out:
# (100958, 4)

# %%
cd /Users/dansari/Documents/GitHub/Identifying-features-to-predict-high-school-assessment-proficiency/Phase1/Data/EDFacts
# Out:
# /Users/dansari/Documents/GitHub/Identifying-features-to-predict-high-school-assessment-proficiency/Phase1/Data/EDFacts

# %%
Math_prof = pandas.read_csv("edfacts_math_merged_ccd.csv")
Math_prof['NCESSCH'] = Math_prof['NCESSCH'].apply(lambda x: '{0:0>12}'.format(x))
Math_prof.head()
# Out:
#      STNAM  FIPST  LEAID_x ST_LEAID_x             LEANM   NCESSCH_old  \
# 0  ALABAMA      1   100005     AL-101  Albertville City  1.000050e+10
# 1  ALABAMA      1   100005     AL-101  Albertville City  1.000050e+10
# 2  ALABAMA      1   100005     AL-101  Albertville City  1.000050e+10
# 3  ALABAMA      1   100005     AL-101  Albertville City  1.000050e+10
# 4  ALABAMA      1   100006     AL-048   Marshall County  1.000060e+10
#
#       ST_SCHID                         SCHNAM   DATE_CUR  \
# 0  AL-101-0010      Albertville Middle School  27-Mar-19
# 1  AL-101-0020        Albertville High School  27-Mar-19
# 2  AL-101-0110        Evans Elementary School  27-Mar-19
# 3  AL-101-0200  Albertville Elementary School  27-Mar-19
# 4  AL-048-0143   Kate Duncan Smith DAR Middle  27-Mar-19
#
#    ALL_MTH00NUMVALID_1718  ... STATE_AGENCY_NO ST_LEAID_y LEAID_y  \
# 0                     802  ...               1     AL-101  100005
# 1                     337  ...               1     AL-101  100005
# 2                     851  ...               1     AL-101  100005
# 3                     902  ...               1     AL-101  100005
# 4                     434  ...               1     AL-048  100006
#
#         NCESSCH   SCHID  SY_STATUS   SCH_TYPE_TEXT  SCH_TYPE       LEVEL  \
# 0  010000500870  100870          1  Regular School         1      Middle
# 1  010000500871  100871          1  Regular School         1        High
# 2  010000500879  100879          1  Regular School         1      Middle
# 3  010000500889  100889          1  Regular School         1  Elementary
# 4  010000600193  100193          1  Regular School         1      Middle
#
#    ALL_MTH00PCTPROF_1718_new
# 0                       47.0
# 1                       37.0
# 2                       37.0
# 3                       53.0
# 4                       56.0
#
# [5 rows x 25 columns]

# %%
Math_prof.shape
# Out:
# (85748, 25)

# %% [markdown]
# ### Merge ccd and crdc file

# %%
merged_ccd_crdc = pandas.merge(left=ccd_master,right=crdc_master_math, how='left', left_on='NCESSCH', right_on='NCESSCH')
merged_ccd_crdc.shape
# Out:
# (19203, 45)

# %%
merged_ccd_crdc.columns
# Out:
# Index(['SCHOOL_YEAR', 'ST', 'SCH_NAME', 'ST_SCHID', 'NCESSCH', 'SCHID',
#        'SY_STATUS', 'SCH_TYPE_TEXT', 'SCH_TYPE', 'LEVEL_x', 'TITLEI_STATUS',
#        'TITLEI_STATUS_TEXT', 'MAGNET_TEXT', 'TEACHERS', 'FARMS_COUNT',
#        'LEA_STATE_x', 'LEA_STATE_NAME_x', 'LEAID_x', 'LEA_NAME_x', 'SCHID_x',
#        'SCH_NAME_x', 'COMBOKEY_x', 'Special_ed_schl_new', 'Magnet_schl_new',
#        'Charter_Schl_new', 'Alternate_schl_new', 'LEVEL_y',
#        'Total_enroll_students', 'SCH_FTETEACH_TOT', 'SCH_FTETEACH_CERT',
#        'SCH_FTETEACH_NOTCERT', 'FTE_teachers_count', 'SalaryforTeachers',
#        'Total_SAT_ACT_students', 'SCH_IBENR_IND_new', 'Total_IB_students',
#        'SCH_APENR_IND_new', 'SCH_APCOURSES', 'SCH_APMATHENR_IND_new',
#        'Total_AP_math_students', 'Total_students_tookAP',
#        'SCH_MATHCLASSES_ALG', 'SCH_MATHCERT_ALG', 'Total_Alg1_enroll_students',
#        'Total_Alg1_pass_students'],
#       dtype='object')

# %%
merged_ccd_crdc_edge = pandas.merge(left=merged_ccd_crdc,right=edge, how='left', left_on='NCESSCH', right_on='NCESSCH')
merged_ccd_crdc_edge.shape
# Out:
# (19203, 48)

# %%
merged_ccd_crdc_edge.columns
# Out:
# Index(['SCHOOL_YEAR', 'ST', 'SCH_NAME', 'ST_SCHID', 'NCESSCH', 'SCHID',
#        'SY_STATUS', 'SCH_TYPE_TEXT', 'SCH_TYPE', 'LEVEL_x', 'TITLEI_STATUS',
#        'TITLEI_STATUS_TEXT', 'MAGNET_TEXT', 'TEACHERS', 'FARMS_COUNT',
#        'LEA_STATE_x', 'LEA_STATE_NAME_x', 'LEAID_x', 'LEA_NAME_x', 'SCHID_x',
#        'SCH_NAME_x', 'COMBOKEY_x', 'Special_ed_schl_new', 'Magnet_schl_new',
#        'Charter_Schl_new', 'Alternate_schl_new', 'LEVEL_y',
#        'Total_enroll_students', 'SCH_FTETEACH_TOT', 'SCH_FTETEACH_CERT',
#        'SCH_FTETEACH_NOTCERT', 'FTE_teachers_count', 'SalaryforTeachers',
#        'Total_SAT_ACT_students', 'SCH_IBENR_IND_new', 'Total_IB_students',
#        'SCH_APENR_IND_new', 'SCH_APCOURSES', 'SCH_APMATHENR_IND_new',
#        'Total_AP_math_students', 'Total_students_tookAP',
#        'SCH_MATHCLASSES_ALG', 'SCH_MATHCERT_ALG', 'Total_Alg1_enroll_students',
#        'Total_Alg1_pass_students', 'NAME', 'Income_Poverty_ratio', 'IPR_SE'],
#       dtype='object')

# %%
merged_ccd_crdc_edge_mathProf = pandas.merge(left=merged_ccd_crdc_edge,right=Math_prof, how='left', left_on='NCESSCH', right_on='NCESSCH')
merged_ccd_crdc_edge_mathProf.shape
# Out:
# (19203, 72)

# %%
merged_ccd_crdc_edge_mathProf.columns
# Out:
# Index(['SCHOOL_YEAR_x', 'ST_x', 'SCH_NAME_x', 'ST_SCHID_x', 'NCESSCH',
#        'SCHID_x', 'SY_STATUS_x', 'SCH_TYPE_TEXT_x', 'SCH_TYPE_x', 'LEVEL_x',
#        'TITLEI_STATUS', 'TITLEI_STATUS_TEXT', 'MAGNET_TEXT', 'TEACHERS',
#        'FARMS_COUNT', 'LEA_STATE_x', 'LEA_STATE_NAME_x', 'LEAID_x_x',
#        'LEA_NAME_x', 'SCHID_x', 'SCH_NAME_x', 'COMBOKEY_x',
#        'Special_ed_schl_new', 'Magnet_schl_new', 'Charter_Schl_new',
#        'Alternate_schl_new', 'LEVEL_y', 'Total_enroll_students',
#        'SCH_FTETEACH_TOT', 'SCH_FTETEACH_CERT', 'SCH_FTETEACH_NOTCERT',
#        'FTE_teachers_count', 'SalaryforTeachers', 'Total_SAT_ACT_students',
#        'SCH_IBENR_IND_new', 'Total_IB_students', 'SCH_APENR_IND_new',
#        'SCH_APCOURSES', 'SCH_APMATHENR_IND_new', 'Total_AP_math_students',
#        'Total_students_tookAP', 'SCH_MATHCLASSES_ALG', 'SCH_MATHCERT_ALG',
#        'Total_Alg1_enroll_students', 'Total_Alg1_pass_students', 'NAME',
#        'Income_Poverty_ratio', 'IPR_SE', 'STNAM', 'FIPST', 'LEAID_x_y',
#        'ST_LEAID_x', 'LEANM', 'NCESSCH_old', 'ST_SCHID_y', 'SCHNAM',
#        'DATE_CUR', 'ALL_MTH00NUMVALID_1718', 'ALL_MTH00PCTPROF_1718',
#        'SCHOOL_YEAR_y', 'ST_y', 'SCH_NAME_y', 'LEA_NAME', 'STATE_AGENCY_NO',
#        'ST_LEAID_y', 'LEAID_y', 'SCHID_y', 'SY_STATUS_y', 'SCH_TYPE_TEXT_y',
#        'SCH_TYPE_y', 'LEVEL', 'ALL_MTH00PCTPROF_1718_new'],
#       dtype='object')

# %%
merged_ccd_crdc_edge_mathProf.drop([col for col in merged_ccd_crdc_edge_mathProf.columns if col.endswith('_y')],axis=1,inplace=True)
merged_ccd_crdc_edge_mathProf.shape
# Out:
# (19203, 60)

# %%
master_math=merged_ccd_crdc_edge_mathProf[['SCHOOL_YEAR_x', 'ST_x', 'NAME', 'NCESSCH','LEVEL','SCH_TYPE_TEXT_x', 'SCH_TYPE_x', 
       'TITLEI_STATUS', 'TITLEI_STATUS_TEXT', 'MAGNET_TEXT', 'TEACHERS',
       'FARMS_COUNT', 'Special_ed_schl_new','Magnet_schl_new', 'Charter_Schl_new', 'Alternate_schl_new', 
       'Total_enroll_students', 
       'SCH_FTETEACH_TOT', 'SCH_FTETEACH_CERT','SCH_FTETEACH_NOTCERT', 'FTE_teachers_count', 'SalaryforTeachers',
       'Total_SAT_ACT_students', 
       'SCH_IBENR_IND_new', 'Total_IB_students',
       'SCH_APENR_IND_new', 'SCH_APCOURSES', 'SCH_APMATHENR_IND_new','Total_AP_math_students', 'Total_students_tookAP',
       'SCH_MATHCLASSES_ALG', 'SCH_MATHCERT_ALG', 'Total_Alg1_enroll_students','Total_Alg1_pass_students', 
       'Income_Poverty_ratio', 'IPR_SE',
       'ALL_MTH00NUMVALID_1718', 'ALL_MTH00PCTPROF_1718_new']]

# %%
master_math.head()
# Out:
#   SCHOOL_YEAR_x ST_x                           NAME       NCESSCH LEVEL  \
# 0     2017-2018   AL        Albertville High School  010000500871  High
# 1     2017-2018   AL             Asbury High School  010000600872  High
# 2     2017-2018   AL            Douglas High School  010000600878  High
# 3     2017-2018   AL   Kate D Smith DAR High School  010000600883  High
# 4     2017-2018   AL  Brindlee Mountain High School  010000601585  High
#
#   SCH_TYPE_TEXT_x  SCH_TYPE_x TITLEI_STATUS         TITLEI_STATUS_TEXT  \
# 0  Regular School           1  SWELIGSWPROG  Title I schoolwide school
# 1  Regular School           1  SWELIGSWPROG  Title I schoolwide school
# 2  Regular School           1  SWELIGSWPROG  Title I schoolwide school
# 3  Regular School           1  SWELIGSWPROG  Title I schoolwide school
# 4  Regular School           1  SWELIGSWPROG  Title I schoolwide school
#
#   MAGNET_TEXT  ...  Total_AP_math_students  Total_students_tookAP  \
# 0          No  ...                    53.0                  286.0
# 1          No  ...                   -18.0                   46.0
# 2          No  ...                    18.0                  244.0
# 3          No  ...                    18.0                  205.0
# 4          No  ...                    11.0                  102.0
#
#    SCH_MATHCLASSES_ALG  SCH_MATHCERT_ALG  Total_Alg1_enroll_students  \
# 0                 23.0              23.0                       450.0
# 1                  4.0               4.0                        63.0
# 2                  4.0               4.0                       117.0
# 3                  4.0               4.0                       105.0
# 4                  4.0               4.0                       161.0
#
#    Total_Alg1_pass_students  Income_Poverty_ratio  IPR_SE  \
# 0                     428.0                 248.0    80.0
# 1                      62.0                 241.0   127.0
# 2                     113.0                 213.0    51.0
# 3                     105.0                 254.0    48.0
# 4                     149.0                 329.0   150.0
#
#    ALL_MTH00NUMVALID_1718  ALL_MTH00PCTPROF_1718_new
# 0                   337.0                       37.0
# 1                   327.0                       34.0
# 2                   130.0                       37.0
# 3                   106.0                       57.0
# 4                   338.0                       31.0
#
# [5 rows x 38 columns]

# %%
sns.heatmap(master_math.isnull(),yticklabels=False,cbar=True,cmap='viridis')

# %%
null_columns=master_math.columns[master_math.isnull().any()]
master_math[null_columns].isnull().sum()
# Out:
# NAME                           207
# LEVEL                         1877
# Special_ed_schl_new           4276
# Magnet_schl_new               4276
# Charter_Schl_new              4276
# Alternate_schl_new            4276
# Total_enroll_students         4276
# SCH_FTETEACH_TOT              4276
# SCH_FTETEACH_CERT             4276
# SCH_FTETEACH_NOTCERT          4276
# FTE_teachers_count            4276
# SalaryforTeachers             4276
# Total_SAT_ACT_students        4276
# SCH_IBENR_IND_new             4276
# Total_IB_students             4276
# SCH_APENR_IND_new             4276
# SCH_APCOURSES                 4276
# SCH_APMATHENR_IND_new         4276
# Total_AP_math_students        4276
# Total_students_tookAP         4276
# SCH_MATHCLASSES_ALG           4276
# SCH_MATHCERT_ALG              4276
# Total_Alg1_enroll_students    4276
# Total_Alg1_pass_students      4276
# Income_Poverty_ratio           207
# IPR_SE                         207
# ALL_MTH00NUMVALID_1718        1877
# ALL_MTH00PCTPROF_1718_new     1877
# dtype: int64

# %%
master_math_new = master_math.dropna(axis = 0, how ='any')

# %%
print("Old data frame length:", len(master_math)) 
print("New data frame length:", len(master_math_new))  
print("Number of rows with at least 1 NA value: ", 
      (len(master_math)-len(master_math_new)))
# Out:
# Old data frame length: 19203
# New data frame length: 14058
# Number of rows with at least 1 NA value:  5145

# %%
master_math_new.describe()
# Out:
#          SCH_TYPE_x      TEACHERS   FARMS_COUNT  Special_ed_schl_new  \
# count  14058.000000  14058.000000  14058.000000         14058.000000
# mean       1.191066     50.043882    390.601864             0.004624
# std        0.723334     41.207369    441.328740             0.067843
# min        1.000000      0.000000      0.000000             0.000000
# 25%        1.000000     18.685000     99.000000             0.000000
# 50%        1.000000     36.555000    225.000000             0.000000
# 75%        1.000000     73.720000    521.000000             0.000000
# max        4.000000    302.000000   4329.000000             1.000000
#
#        Magnet_schl_new  Charter_Schl_new  Alternate_schl_new  \
# count     14058.000000      14058.000000        14058.000000
# mean          0.059041          0.051785            0.047304
# std           0.235710          0.221601            0.212296
# min           0.000000          0.000000            0.000000
# 25%           0.000000          0.000000            0.000000
# 50%           0.000000          0.000000            0.000000
# 75%           0.000000          0.000000            0.000000
# max           1.000000          1.000000            1.000000
#
#        Total_enroll_students  SCH_FTETEACH_TOT  SCH_FTETEACH_CERT  ...  \
# count           14058.000000      14058.000000       14058.000000  ...
# mean              839.834329         52.102655          50.760906  ...
# std               768.655312         42.485612          41.803474  ...
# min                10.000000          0.120000           0.000000  ...
# 25%               251.250000         19.700000          19.000000  ...
# 50%               551.000000         38.045000          37.000000  ...
# 75%              1266.000000         76.522500          74.490000  ...
# max              4996.000000        361.000000         361.000000  ...
#
#        Total_AP_math_students  Total_students_tookAP  SCH_MATHCLASSES_ALG  \
# count            14058.000000           14058.000000         14058.000000
# mean                29.689643             122.586001            11.096173
# std                 73.399144             213.282702            13.137607
# min                -18.000000             -18.000000             1.000000
# 25%                -18.000000             -18.000000             3.000000
# 50%                  8.000000              32.000000             7.000000
# 75%                 45.000000             172.000000            15.000000
# max               1522.000000            3162.000000           472.000000
#
#        SCH_MATHCERT_ALG  Total_Alg1_enroll_students  Total_Alg1_pass_students  \
# count      14058.000000                14058.000000              14058.000000
# mean           9.341727                  169.587210                131.209987
# std           11.942210                  178.085323                141.397109
# min            0.000000                  -18.000000                -18.000000
# 25%            2.000000                   41.000000                 29.000000
# 50%            6.000000                  102.000000                 79.000000
# 75%           13.000000                  245.000000                193.000000
# max          472.000000                 1523.000000               1345.000000
#
#        Income_Poverty_ratio        IPR_SE  ALL_MTH00NUMVALID_1718  \
# count          14058.000000  14058.000000            14058.000000
# mean             294.567150     70.911509              239.016716
# std              140.864968     38.312622              231.862112
# min               48.000000      2.000000                6.000000
# 25%              204.000000     42.000000               73.000000
# 50%              263.000000     62.000000              164.000000
# 75%              343.000000     91.000000              337.000000
# max              979.000000    330.000000             2274.000000
#
#        ALL_MTH00PCTPROF_1718_new
# count               14058.000000
# mean                   38.644473
# std                    23.649085
# min                     1.000000
# 25%                    20.000000
# 50%                    37.000000
# 75%                    52.000000
# max                    99.000000
#
# [8 rows x 29 columns]

# %%
master_math_new.dtypes
# Out:
# SCHOOL_YEAR_x                  object
# ST_x                           object
# NAME                           object
# NCESSCH                        object
# LEVEL                          object
# SCH_TYPE_TEXT_x                object
# SCH_TYPE_x                      int64
# TITLEI_STATUS                  object
# TITLEI_STATUS_TEXT             object
# MAGNET_TEXT                    object
# TEACHERS                      float64
# FARMS_COUNT                   float64
# Special_ed_schl_new           float64
# Magnet_schl_new               float64
# Charter_Schl_new              float64
# Alternate_schl_new            float64
# Total_enroll_students         float64
# SCH_FTETEACH_TOT              float64
# SCH_FTETEACH_CERT             float64
# SCH_FTETEACH_NOTCERT          float64
# FTE_teachers_count            float64
# SalaryforTeachers             float64
# Total_SAT_ACT_students        float64
# SCH_IBENR_IND_new             float64
# Total_IB_students             float64
# SCH_APENR_IND_new             float64
# SCH_APCOURSES                 float64
# SCH_APMATHENR_IND_new         float64
# Total_AP_math_students        float64
# Total_students_tookAP         float64
# SCH_MATHCLASSES_ALG           float64
# SCH_MATHCERT_ALG              float64
# Total_Alg1_enroll_students    float64
# Total_Alg1_pass_students      float64
# Income_Poverty_ratio          float64
# IPR_SE                        float64
# ALL_MTH00NUMVALID_1718        float64
# ALL_MTH00PCTPROF_1718_new     float64
# dtype: object

# %%
master_math_new.hist(figsize=(12,12))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7fd86b896be0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fd86b9b6130>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fd86c296550>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fd86c24b250>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fd86c2749d0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7fd86c95b0d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fd86c95b1c0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fd86c9a79a0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fd86ca05850>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fd86ca8efd0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7fd86d10e790>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fd86d139f10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fd86d19d6d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fd86d1c5e50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fd86d30d610>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7fd86d337d90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fd86d36c550>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fd86d396cd0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fd86d449490>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fd86d472c10>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7fd86d7ae3d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fd86d8b8b50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fd86da0b310>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fd86da32a90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fd86dd2b250>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7fd86dd569d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fd86dd89190>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fd86ddb3910>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fd86ddde130>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fd86de12790>]],
#       dtype=object)

# %%
corr = master_math.corr()

# %%
plt.figure(figsize=(12,8))
plt.figure(figsize=(20,10))
sns.heatmap(corr, cmap="Greens",annot=True)

# %%
X = master_math_new.iloc[:,0:20]  #independent columns
y = master_math_new.iloc[:,-1]    #target column i.e price range
#get correlations of each features in dataset
corrmat = master_math_new.corr()
top_corr_features = corrmat.index
plt.figure(figsize=(20,10))
#plot heat map
g=sns.heatmap(master_math_new[top_corr_features].corr(),annot=True,cmap="RdYlGn")
