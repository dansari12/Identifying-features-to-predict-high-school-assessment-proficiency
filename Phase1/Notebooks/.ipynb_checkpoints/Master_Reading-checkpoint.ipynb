# %%
import pandas
pandas.__version__
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
pip install --user scikit-learn
# Out:
# Requirement already satisfied: scikit-learn in /opt/anaconda3/lib/python3.8/site-packages (0.24.1)
# Requirement already satisfied: joblib>=0.11 in /opt/anaconda3/lib/python3.8/site-packages (from scikit-learn) (0.16.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /opt/anaconda3/lib/python3.8/site-packages (from scikit-learn) (2.1.0)
# Requirement already satisfied: scipy>=0.19.1 in /opt/anaconda3/lib/python3.8/site-packages (from scikit-learn) (1.5.0)
# Requirement already satisfied: numpy>=1.13.3 in /opt/anaconda3/lib/python3.8/site-packages (from scikit-learn) (1.18.5)
# Note: you may need to restart the kernel to use updated packages.

# %%
import sys
sys.path.append("/home/nbuser/.local/lib/python2.7/site-packages")

# %%
cd /Users/dansari/Documents/GitHub/Identifying-features-to-predict-high-school-assessment-proficiency/Phase1/Data/CCD
# Out:
# /Users/dansari/Documents/GitHub/Identifying-features-to-predict-high-school-assessment-proficiency/Phase1/Data/CCD

# %%
ccd_master = pandas.read_csv("Clean_ccd_master.csv")
ccd_master['NCESSCH'] = ccd_master['NCESSCH'].apply(lambda x: '{0:0>12}'.format(x))
ccd_master.head()
# Out:
#   SCHOOL_YEAR  ST                       SCH_NAME     ST_SCHID       NCESSCH  \
# 0   2017-2018  AL        Albertville High School  AL-101-0020  010000500871
# 1   2017-2018  AL             Asbury High School  AL-048-0030  010000600872
# 2   2017-2018  AL            Douglas High School  AL-048-0100  010000600878
# 3   2017-2018  AL   Kate D Smith DAR High School  AL-048-0140  010000600883
# 4   2017-2018  AL  Brindlee Mountain High School  AL-048-0042  010000601585
#
#     SCHID  SY_STATUS   SCH_TYPE_TEXT  SCH_TYPE LEVEL TITLEI_STATUS  \
# 0  100871          1  Regular School         1  High  SWELIGSWPROG
# 1  100872          1  Regular School         1  High  SWELIGSWPROG
# 2  100878          1  Regular School         1  High  SWELIGSWPROG
# 3  100883          1  Regular School         1  High  SWELIGSWPROG
# 4  101585          1  Regular School         1  High  SWELIGSWPROG
#
#           TITLEI_STATUS_TEXT MAGNET_TEXT  TEACHERS  FARMS_COUNT
# 0  Title I schoolwide school          No     77.00        832.0
# 1  Title I schoolwide school          No     28.64        450.0
# 2  Title I schoolwide school          No     30.87        429.0
# 3  Title I schoolwide school          No     24.04        211.0
# 4  Title I schoolwide school          No     31.26        415.0

# %%
ccd_master.shape
# Out:
# (19203, 15)

# %%
cd /Users/dansari/Documents/GitHub/Identifying-features-to-predict-high-school-assessment-proficiency/Phase1/Data/CRDC
# Out:
# /Users/dansari/Documents/GitHub/Identifying-features-to-predict-high-school-assessment-proficiency/Phase1/Data/CRDC

# %%
crdc_master_read = pandas.read_csv("Clean_crdc_master_read.csv")
crdc_master_read['NCESSCH'] = crdc_master_read['NCESSCH'].apply(lambda x: '{0:0>12}'.format(x))
crdc_master_read.head()
# Out:
#   LEA_STATE_x LEA_STATE_NAME_x  LEAID_x        LEA_NAME_x  SCHID_x  \
# 0          AL          ALABAMA   100005  Albertville City      871
# 1          AL          ALABAMA   100006   Marshall County      872
# 2          AL          ALABAMA   100006   Marshall County      878
# 3          AL          ALABAMA   100006   Marshall County      883
# 4          AL          ALABAMA   100006   Marshall County     1585
#
#                       SCH_NAME_x   COMBOKEY_x  Special_ed_schl_new  \
# 0        Albertville High School  10000500871                    0
# 1             Asbury High School  10000600872                    0
# 2            Douglas High School  10000600878                    0
# 3   Kate D Smith DAR High School  10000600883                    0
# 4  Brindlee Mountain High School  10000601585                    0
#
#    Magnet_schl_new  Charter_Schl_new  ...  FTE_teachers_count  \
# 0                0                 0  ...               72.88
# 1                0                 0  ...               32.00
# 2                0                 0  ...               36.00
# 3                0                 0  ...               29.00
# 4                0                 0  ...               37.00
#
#   SalaryforTeachers Total_SAT_ACT_students  SCH_IBENR_IND_new  \
# 0        3780956.34                  363.0                0.0
# 1        1551823.89                   61.0                0.0
# 2        1654974.93                  142.0                0.0
# 3        1256524.51                  103.0                0.0
# 4        1540288.05                   76.0                0.0
#
#    Total_IB_students  SCH_APENR_IND_new  SCH_APCOURSES  SCH_APOTHENR_IND_new  \
# 0              -18.0                1.0            8.0                   1.0
# 1              -18.0                1.0            3.0                   1.0
# 2              -18.0                1.0            6.0                   1.0
# 3              -18.0                1.0            6.0                   1.0
# 4              -18.0                1.0            5.0                   1.0
#
#    Total_AP_other_students  Total_students_tookAP
# 0                    179.0                  286.0
# 1                     33.0                   46.0
# 2                    185.0                  244.0
# 3                    116.0                  205.0
# 4                     76.0                  102.0
#
# [5 rows x 27 columns]

# %%
crdc_master_read.shape
# Out:
# (17208, 27)

# %%
cd /Users/dansari/Documents/GitHub/Identifying-features-to-predict-high-school-assessment-proficiency/Phase1/Data/EDGE
# Out:
# /Users/dansari/Documents/GitHub/Identifying-features-to-predict-high-school-assessment-proficiency/Phase1/Data/EDGE

# %%
edge = pandas.read_csv("Clean_EDGE.csv")
edge['NCESSCH'] = edge['NCESSCH'].apply(lambda x: '{0:0>12}'.format(x))
edge.head()
# Out:
#         NCESSCH                                 NAME  Income_Poverty_ratio  \
# 0  010000500870            Albertville Middle School                   245
# 1  010000500871              Albertville High School                   248
# 2  010000500879              Evans Elementary School                   174
# 3  010000500889        Albertville Elementary School                   236
# 4  010000501616  Big Spring Lake Kindergarten School                   480
#
#    IPR_SE
# 0      80
# 1      80
# 2      91
# 3     105
# 4     120

# %%
edge.shape
# Out:
# (100958, 4)

# %%
cd /Users/dansari/Documents/GitHub/Identifying-features-to-predict-high-school-assessment-proficiency/Phase1/Data/EDFacts
# Out:
# /Users/dansari/Documents/GitHub/Identifying-features-to-predict-high-school-assessment-proficiency/Phase1/Data/EDFacts

# %%
Eng_prof = pandas.read_csv("edfacts_eng_merged_ccd.csv")
Eng_prof['NCESSCH'] = Eng_prof['NCESSCH'].apply(lambda x: '{0:0>12}'.format(x))
Eng_prof.head()
# Out:
#      STNAM  FIPST  LEAID_x ST_LEAID_x             LEANM   NCESSCH_old  \
# 0  ALABAMA      1   100005     AL-101  Albertville City  1.000050e+10
# 1  ALABAMA      1   100005     AL-101  Albertville City  1.000050e+10
# 2  ALABAMA      1   100005     AL-101  Albertville City  1.000050e+10
# 3  ALABAMA      1   100005     AL-101  Albertville City  1.000050e+10
# 4  ALABAMA      1   100006     AL-048   Marshall County  1.000060e+10
#
#       ST_SCHID                         SCHNAM   DATE_CUR  \
# 0  AL-101-0010      Albertville Middle School  27-Mar-19
# 1  AL-101-0020        Albertville High School  27-Mar-19
# 2  AL-101-0110        Evans Elementary School  27-Mar-19
# 3  AL-101-0200  Albertville Elementary School  27-Mar-19
# 4  AL-048-0143   Kate Duncan Smith DAR Middle  27-Mar-19
#
#    ALL_RLA00NUMVALID_1718  ... STATE_AGENCY_NO ST_LEAID_y LEAID_y  \
# 0                     801  ...               1     AL-101  100005
# 1                     337  ...               1     AL-101  100005
# 2                     848  ...               1     AL-101  100005
# 3                     899  ...               1     AL-101  100005
# 4                     433  ...               1     AL-048  100006
#
#         NCESSCH   SCHID  SY_STATUS   SCH_TYPE_TEXT  SCH_TYPE       LEVEL  \
# 0  010000500870  100870          1  Regular School         1      Middle
# 1  010000500871  100871          1  Regular School         1        High
# 2  010000500879  100879          1  Regular School         1      Middle
# 3  010000500889  100889          1  Regular School         1  Elementary
# 4  010000600193  100193          1  Regular School         1      Middle
#
#    ALL_RLA00PCTPROF_1718_new
# 0                       43.0
# 1                       32.0
# 2                       34.0
# 3                       41.0
# 4                       52.0
#
# [5 rows x 25 columns]

# %%
Eng_prof.shape
# Out:
# (86840, 25)

# %% [markdown]
# ### Merge ccd and crdc file

# %%
merged_ccd_crdc = pandas.merge(left=ccd_master,right=crdc_master_read, how='left', left_on='NCESSCH', right_on='NCESSCH')
merged_ccd_crdc.shape
# Out:
# (19203, 41)

# %%
merged_ccd_crdc.columns
# Out:
# Index(['SCHOOL_YEAR', 'ST', 'SCH_NAME', 'ST_SCHID', 'NCESSCH', 'SCHID',
#        'SY_STATUS', 'SCH_TYPE_TEXT', 'SCH_TYPE', 'LEVEL_x', 'TITLEI_STATUS',
#        'TITLEI_STATUS_TEXT', 'MAGNET_TEXT', 'TEACHERS', 'FARMS_COUNT',
#        'LEA_STATE_x', 'LEA_STATE_NAME_x', 'LEAID_x', 'LEA_NAME_x', 'SCHID_x',
#        'SCH_NAME_x', 'COMBOKEY_x', 'Special_ed_schl_new', 'Magnet_schl_new',
#        'Charter_Schl_new', 'Alternate_schl_new', 'LEVEL_y',
#        'Total_enroll_students', 'SCH_FTETEACH_TOT', 'SCH_FTETEACH_CERT',
#        'SCH_FTETEACH_NOTCERT', 'FTE_teachers_count', 'SalaryforTeachers',
#        'Total_SAT_ACT_students', 'SCH_IBENR_IND_new', 'Total_IB_students',
#        'SCH_APENR_IND_new', 'SCH_APCOURSES', 'SCH_APOTHENR_IND_new',
#        'Total_AP_other_students', 'Total_students_tookAP'],
#       dtype='object')

# %%
#merged_ccd_crdc.head().T

# %%
merged_ccd_crdc_edge = pandas.merge(left=merged_ccd_crdc,right=edge, how='left', left_on='NCESSCH', right_on='NCESSCH')
merged_ccd_crdc_edge.shape
# Out:
# (19203, 44)

# %%
merged_ccd_crdc_edge.columns
# Out:
# Index(['SCHOOL_YEAR', 'ST', 'SCH_NAME', 'ST_SCHID', 'NCESSCH', 'SCHID',
#        'SY_STATUS', 'SCH_TYPE_TEXT', 'SCH_TYPE', 'LEVEL_x', 'TITLEI_STATUS',
#        'TITLEI_STATUS_TEXT', 'MAGNET_TEXT', 'TEACHERS', 'FARMS_COUNT',
#        'LEA_STATE_x', 'LEA_STATE_NAME_x', 'LEAID_x', 'LEA_NAME_x', 'SCHID_x',
#        'SCH_NAME_x', 'COMBOKEY_x', 'Special_ed_schl_new', 'Magnet_schl_new',
#        'Charter_Schl_new', 'Alternate_schl_new', 'LEVEL_y',
#        'Total_enroll_students', 'SCH_FTETEACH_TOT', 'SCH_FTETEACH_CERT',
#        'SCH_FTETEACH_NOTCERT', 'FTE_teachers_count', 'SalaryforTeachers',
#        'Total_SAT_ACT_students', 'SCH_IBENR_IND_new', 'Total_IB_students',
#        'SCH_APENR_IND_new', 'SCH_APCOURSES', 'SCH_APOTHENR_IND_new',
#        'Total_AP_other_students', 'Total_students_tookAP', 'NAME',
#        'Income_Poverty_ratio', 'IPR_SE'],
#       dtype='object')

# %%
#merged_ccd_crdc_edge.head().T

# %%
merged_ccd_crdc_edge_engProf = pandas.merge(left=merged_ccd_crdc_edge,right=Eng_prof, how='left', left_on='NCESSCH', right_on='NCESSCH')
merged_ccd_crdc_edge_engProf.shape
# Out:
# (19203, 68)

# %%
merged_ccd_crdc_edge_engProf.columns
# Out:
# Index(['SCHOOL_YEAR_x', 'ST_x', 'SCH_NAME_x', 'ST_SCHID_x', 'NCESSCH',
#        'SCHID_x', 'SY_STATUS_x', 'SCH_TYPE_TEXT_x', 'SCH_TYPE_x', 'LEVEL_x',
#        'TITLEI_STATUS', 'TITLEI_STATUS_TEXT', 'MAGNET_TEXT', 'TEACHERS',
#        'FARMS_COUNT', 'LEA_STATE_x', 'LEA_STATE_NAME_x', 'LEAID_x_x',
#        'LEA_NAME_x', 'SCHID_x', 'SCH_NAME_x', 'COMBOKEY_x',
#        'Special_ed_schl_new', 'Magnet_schl_new', 'Charter_Schl_new',
#        'Alternate_schl_new', 'LEVEL_y', 'Total_enroll_students',
#        'SCH_FTETEACH_TOT', 'SCH_FTETEACH_CERT', 'SCH_FTETEACH_NOTCERT',
#        'FTE_teachers_count', 'SalaryforTeachers', 'Total_SAT_ACT_students',
#        'SCH_IBENR_IND_new', 'Total_IB_students', 'SCH_APENR_IND_new',
#        'SCH_APCOURSES', 'SCH_APOTHENR_IND_new', 'Total_AP_other_students',
#        'Total_students_tookAP', 'NAME', 'Income_Poverty_ratio', 'IPR_SE',
#        'STNAM', 'FIPST', 'LEAID_x_y', 'ST_LEAID_x', 'LEANM', 'NCESSCH_old',
#        'ST_SCHID_y', 'SCHNAM', 'DATE_CUR', 'ALL_RLA00NUMVALID_1718',
#        'ALL_RLA00PCTPROF_1718', 'SCHOOL_YEAR_y', 'ST_y', 'SCH_NAME_y',
#        'LEA_NAME', 'STATE_AGENCY_NO', 'ST_LEAID_y', 'LEAID_y', 'SCHID_y',
#        'SY_STATUS_y', 'SCH_TYPE_TEXT_y', 'SCH_TYPE_y', 'LEVEL',
#        'ALL_RLA00PCTPROF_1718_new'],
#       dtype='object')

# %%
merged_ccd_crdc_edge_engProf.drop([col for col in merged_ccd_crdc_edge_engProf.columns if col.endswith('_y')],axis=1,inplace=True)
merged_ccd_crdc_edge_engProf.shape
# Out:
# (19203, 56)

# %%
merged_ccd_crdc_edge_engProf.columns
# Out:
# Index(['SCHOOL_YEAR_x', 'ST_x', 'SCH_NAME_x', 'ST_SCHID_x', 'NCESSCH',
#        'SCHID_x', 'SY_STATUS_x', 'SCH_TYPE_TEXT_x', 'SCH_TYPE_x', 'LEVEL_x',
#        'TITLEI_STATUS', 'TITLEI_STATUS_TEXT', 'MAGNET_TEXT', 'TEACHERS',
#        'FARMS_COUNT', 'LEA_STATE_x', 'LEA_STATE_NAME_x', 'LEAID_x_x',
#        'LEA_NAME_x', 'SCHID_x', 'SCH_NAME_x', 'COMBOKEY_x',
#        'Special_ed_schl_new', 'Magnet_schl_new', 'Charter_Schl_new',
#        'Alternate_schl_new', 'Total_enroll_students', 'SCH_FTETEACH_TOT',
#        'SCH_FTETEACH_CERT', 'SCH_FTETEACH_NOTCERT', 'FTE_teachers_count',
#        'SalaryforTeachers', 'Total_SAT_ACT_students', 'SCH_IBENR_IND_new',
#        'Total_IB_students', 'SCH_APENR_IND_new', 'SCH_APCOURSES',
#        'SCH_APOTHENR_IND_new', 'Total_AP_other_students',
#        'Total_students_tookAP', 'NAME', 'Income_Poverty_ratio', 'IPR_SE',
#        'STNAM', 'FIPST', 'ST_LEAID_x', 'LEANM', 'NCESSCH_old', 'SCHNAM',
#        'DATE_CUR', 'ALL_RLA00NUMVALID_1718', 'ALL_RLA00PCTPROF_1718',
#        'LEA_NAME', 'STATE_AGENCY_NO', 'LEVEL', 'ALL_RLA00PCTPROF_1718_new'],
#       dtype='object')

# %%
master_reading=merged_ccd_crdc_edge_engProf[['SCHOOL_YEAR_x', 'ST_x','NAME', 'NCESSCH', 'LEVEL', 'SCH_TYPE_TEXT_x', 'SCH_TYPE_x',
       'TITLEI_STATUS', 'TITLEI_STATUS_TEXT', 'MAGNET_TEXT', 'TEACHERS',
       'FARMS_COUNT', 'Special_ed_schl_new','Magnet_schl_new', 'Charter_Schl_new', 'Alternate_schl_new',
       'Total_enroll_students', 
       'SCH_FTETEACH_TOT', 'SCH_FTETEACH_CERT','SCH_FTETEACH_NOTCERT', 'FTE_teachers_count', 'SalaryforTeachers',
       'Total_SAT_ACT_students', 
       'SCH_IBENR_IND_new', 'Total_IB_students',
       'SCH_APENR_IND_new', 'SCH_APCOURSES', 'SCH_APOTHENR_IND_new','Total_AP_other_students', 'Total_students_tookAP', 
       'Income_Poverty_ratio', 'IPR_SE', 
       'ALL_RLA00NUMVALID_1718','ALL_RLA00PCTPROF_1718_new']]

# %%
master_reading.shape
# Out:
# (19203, 34)

# %%
master_reading.head().T
# Out:
#                                                    0  \
# SCHOOL_YEAR_x                              2017-2018
# ST_x                                              AL
# NAME                         Albertville High School
# NCESSCH                                 010000500871
# LEVEL                                           High
# SCH_TYPE_TEXT_x                       Regular School
# SCH_TYPE_x                                         1
# TITLEI_STATUS                           SWELIGSWPROG
# TITLEI_STATUS_TEXT         Title I schoolwide school
# MAGNET_TEXT                                       No
# TEACHERS                                          77
# FARMS_COUNT                                      832
# Special_ed_schl_new                                0
# Magnet_schl_new                                    0
# Charter_Schl_new                                   0
# Alternate_schl_new                                 0
# Total_enroll_students                           1449
# SCH_FTETEACH_TOT                               78.17
# SCH_FTETEACH_CERT                              71.17
# SCH_FTETEACH_NOTCERT                               7
# FTE_teachers_count                             72.88
# SalaryforTeachers                        3.78096e+06
# Total_SAT_ACT_students                           363
# SCH_IBENR_IND_new                                  0
# Total_IB_students                                -18
# SCH_APENR_IND_new                                  1
# SCH_APCOURSES                                      8
# SCH_APOTHENR_IND_new                               1
# Total_AP_other_students                          179
# Total_students_tookAP                            286
# Income_Poverty_ratio                             248
# IPR_SE                                            80
# ALL_RLA00NUMVALID_1718                           337
# ALL_RLA00PCTPROF_1718_new                         32
#
#                                                    1  \
# SCHOOL_YEAR_x                              2017-2018
# ST_x                                              AL
# NAME                              Asbury High School
# NCESSCH                                 010000600872
# LEVEL                                           High
# SCH_TYPE_TEXT_x                       Regular School
# SCH_TYPE_x                                         1
# TITLEI_STATUS                           SWELIGSWPROG
# TITLEI_STATUS_TEXT         Title I schoolwide school
# MAGNET_TEXT                                       No
# TEACHERS                                       28.64
# FARMS_COUNT                                      450
# Special_ed_schl_new                                0
# Magnet_schl_new                                    0
# Charter_Schl_new                                   0
# Alternate_schl_new                                 0
# Total_enroll_students                            547
# SCH_FTETEACH_TOT                                  32
# SCH_FTETEACH_CERT                                 31
# SCH_FTETEACH_NOTCERT                               1
# FTE_teachers_count                                32
# SalaryforTeachers                        1.55182e+06
# Total_SAT_ACT_students                            61
# SCH_IBENR_IND_new                                  0
# Total_IB_students                                -18
# SCH_APENR_IND_new                                  1
# SCH_APCOURSES                                      3
# SCH_APOTHENR_IND_new                               1
# Total_AP_other_students                           33
# Total_students_tookAP                             46
# Income_Poverty_ratio                             241
# IPR_SE                                           127
# ALL_RLA00NUMVALID_1718                           327
# ALL_RLA00PCTPROF_1718_new                         30
#
#                                                    2  \
# SCHOOL_YEAR_x                              2017-2018
# ST_x                                              AL
# NAME                             Douglas High School
# NCESSCH                                 010000600878
# LEVEL                                           High
# SCH_TYPE_TEXT_x                       Regular School
# SCH_TYPE_x                                         1
# TITLEI_STATUS                           SWELIGSWPROG
# TITLEI_STATUS_TEXT         Title I schoolwide school
# MAGNET_TEXT                                       No
# TEACHERS                                       30.87
# FARMS_COUNT                                      429
# Special_ed_schl_new                                0
# Magnet_schl_new                                    0
# Charter_Schl_new                                   0
# Alternate_schl_new                                 0
# Total_enroll_students                            591
# SCH_FTETEACH_TOT                                  36
# SCH_FTETEACH_CERT                                 36
# SCH_FTETEACH_NOTCERT                               0
# FTE_teachers_count                                36
# SalaryforTeachers                        1.65497e+06
# Total_SAT_ACT_students                           142
# SCH_IBENR_IND_new                                  0
# Total_IB_students                                -18
# SCH_APENR_IND_new                                  1
# SCH_APCOURSES                                      6
# SCH_APOTHENR_IND_new                               1
# Total_AP_other_students                          185
# Total_students_tookAP                            244
# Income_Poverty_ratio                             213
# IPR_SE                                            51
# ALL_RLA00NUMVALID_1718                           130
# ALL_RLA00PCTPROF_1718_new                         42
#
#                                                       3  \
# SCHOOL_YEAR_x                                 2017-2018
# ST_x                                                 AL
# NAME                       Kate D Smith DAR High School
# NCESSCH                                    010000600883
# LEVEL                                              High
# SCH_TYPE_TEXT_x                          Regular School
# SCH_TYPE_x                                            1
# TITLEI_STATUS                              SWELIGSWPROG
# TITLEI_STATUS_TEXT            Title I schoolwide school
# MAGNET_TEXT                                          No
# TEACHERS                                          24.04
# FARMS_COUNT                                         211
# Special_ed_schl_new                                   0
# Magnet_schl_new                                       0
# Charter_Schl_new                                      0
# Alternate_schl_new                                    0
# Total_enroll_students                               452
# SCH_FTETEACH_TOT                                     29
# SCH_FTETEACH_CERT                                    29
# SCH_FTETEACH_NOTCERT                                  0
# FTE_teachers_count                                   29
# SalaryforTeachers                           1.25652e+06
# Total_SAT_ACT_students                              103
# SCH_IBENR_IND_new                                     0
# Total_IB_students                                   -18
# SCH_APENR_IND_new                                     1
# SCH_APCOURSES                                         6
# SCH_APOTHENR_IND_new                                  1
# Total_AP_other_students                             116
# Total_students_tookAP                               205
# Income_Poverty_ratio                                254
# IPR_SE                                               48
# ALL_RLA00NUMVALID_1718                              106
# ALL_RLA00PCTPROF_1718_new                            57
#
#                                                        4
# SCHOOL_YEAR_x                                  2017-2018
# ST_x                                                  AL
# NAME                       Brindlee Mountain High School
# NCESSCH                                     010000601585
# LEVEL                                               High
# SCH_TYPE_TEXT_x                           Regular School
# SCH_TYPE_x                                             1
# TITLEI_STATUS                               SWELIGSWPROG
# TITLEI_STATUS_TEXT             Title I schoolwide school
# MAGNET_TEXT                                           No
# TEACHERS                                           31.26
# FARMS_COUNT                                          415
# Special_ed_schl_new                                    0
# Magnet_schl_new                                        0
# Charter_Schl_new                                       0
# Alternate_schl_new                                     0
# Total_enroll_students                                632
# SCH_FTETEACH_TOT                                      37
# SCH_FTETEACH_CERT                                     36
# SCH_FTETEACH_NOTCERT                                   1
# FTE_teachers_count                                    37
# SalaryforTeachers                            1.54029e+06
# Total_SAT_ACT_students                                76
# SCH_IBENR_IND_new                                      0
# Total_IB_students                                    -18
# SCH_APENR_IND_new                                      1
# SCH_APCOURSES                                          5
# SCH_APOTHENR_IND_new                                   1
# Total_AP_other_students                               76
# Total_students_tookAP                                102
# Income_Poverty_ratio                                 329
# IPR_SE                                               150
# ALL_RLA00NUMVALID_1718                               338
# ALL_RLA00PCTPROF_1718_new                             31

# %%
sns.heatmap(master_reading.isnull(),yticklabels=False,cbar=True,cmap='viridis')

# %%
null_columns=master_reading.columns[master_reading.isnull().any()]
master_reading[null_columns].isnull().sum()
# Out:
# NAME                          207
# LEVEL                        1726
# Special_ed_schl_new          3584
# Magnet_schl_new              3584
# Charter_Schl_new             3584
# Alternate_schl_new           3584
# Total_enroll_students        3584
# SCH_FTETEACH_TOT             3584
# SCH_FTETEACH_CERT            3584
# SCH_FTETEACH_NOTCERT         3584
# FTE_teachers_count           3584
# SalaryforTeachers            3584
# Total_SAT_ACT_students       3584
# SCH_IBENR_IND_new            3584
# Total_IB_students            3584
# SCH_APENR_IND_new            3584
# SCH_APCOURSES                3584
# SCH_APOTHENR_IND_new         3584
# Total_AP_other_students      3584
# Total_students_tookAP        3584
# Income_Poverty_ratio          207
# IPR_SE                        207
# ALL_RLA00NUMVALID_1718       1726
# ALL_RLA00PCTPROF_1718_new    1726
# dtype: int64

# %%
master_reading_new = master_reading.dropna(axis = 0, how ='any')

# %%
print("Old data frame length:", len(master_reading)) 
print("New data frame length:", len(master_reading_new))  
print("Number of rows with at least 1 NA value: ", 
      (len(master_reading)-len(master_reading_new)))
# Out:
# Old data frame length: 19203
# New data frame length: 14793
# Number of rows with at least 1 NA value:  4410

# %%
sns.heatmap(master_reading_new.isnull(),yticklabels=False,cbar=True,cmap='viridis')

# %%
master_reading_new.describe()
# Out:
#          SCH_TYPE_x      TEACHERS   FARMS_COUNT  Special_ed_schl_new  \
# count  14793.000000  14793.000000  14793.000000         14793.000000
# mean       1.204286     50.066712    384.972284             0.004867
# std        0.746392     41.568114    435.941109             0.069597
# min        1.000000      0.000000      0.000000             0.000000
# 25%        1.000000     18.300000     97.000000             0.000000
# 50%        1.000000     36.300000    223.000000             0.000000
# 75%        1.000000     74.010000    512.000000             0.000000
# max        4.000000    330.360000   4329.000000             1.000000
#
#        Magnet_schl_new  Charter_Schl_new  Alternate_schl_new  \
# count     14793.000000      14793.000000        14793.000000
# mean          0.061989          0.052322            0.051443
# std           0.241143          0.222683            0.220908
# min           0.000000          0.000000            0.000000
# 25%           0.000000          0.000000            0.000000
# 50%           0.000000          0.000000            0.000000
# 75%           0.000000          0.000000            0.000000
# max           1.000000          1.000000            1.000000
#
#        Total_enroll_students  SCH_FTETEACH_TOT  SCH_FTETEACH_CERT  ...  \
# count           14793.000000      14793.000000       14793.000000  ...
# mean              836.186845         52.106122          50.710545  ...
# std               768.211420         42.855994          42.154294  ...
# min                 8.000000          0.010000           0.000000  ...
# 25%               249.000000         19.250000          18.700000  ...
# 50%               548.000000         38.000000          37.000000  ...
# 75%              1262.000000         76.800000          74.650000  ...
# max              4996.000000        396.000000         382.470000  ...
#
#        Total_IB_students  SCH_APENR_IND_new  SCH_APCOURSES  \
# count       14793.000000       14793.000000   14793.000000
# mean           -7.025417           0.701075       5.120462
# std            66.282175           0.457802      11.491547
# min           -18.000000           0.000000      -9.000000
# 25%           -18.000000           0.000000      -9.000000
# 50%           -18.000000           1.000000       5.000000
# 75%           -18.000000           1.000000      13.000000
# max          1335.000000           1.000000      82.000000
#
#        SCH_APOTHENR_IND_new  Total_AP_other_students  Total_students_tookAP  \
# count          14793.000000             14793.000000           14793.000000
# mean              -2.031975               138.134050             122.825255
# std                4.554533               234.848046             215.320172
# min               -9.000000               -18.000000             -18.000000
# 25%               -9.000000               -18.000000             -18.000000
# 50%                1.000000                38.000000              32.000000
# 75%                1.000000               198.000000             171.000000
# max                1.000000              3173.000000            3162.000000
#
#        Income_Poverty_ratio        IPR_SE  ALL_RLA00NUMVALID_1718  \
# count          14793.000000  14793.000000            14793.000000
# mean             296.198607     71.260731              249.872913
# std              141.575491     38.503395              254.945567
# min               48.000000      2.000000                6.000000
# 25%              205.000000     42.000000               74.000000
# 50%              264.000000     63.000000              166.000000
# 75%              345.000000     92.000000              342.000000
# max              979.000000    330.000000             2484.000000
#
#        ALL_RLA00PCTPROF_1718_new
# count               14793.000000
# mean                   50.221963
# std                    23.421256
# min                     1.000000
# 25%                    33.000000
# 50%                    49.500000
# 75%                    67.000000
# max                    99.000000
#
# [8 rows x 25 columns]

# %%
master_reading_new.dtypes
# Out:
# SCHOOL_YEAR_x                 object
# ST_x                          object
# NAME                          object
# NCESSCH                       object
# LEVEL                         object
# SCH_TYPE_TEXT_x               object
# SCH_TYPE_x                     int64
# TITLEI_STATUS                 object
# TITLEI_STATUS_TEXT            object
# MAGNET_TEXT                   object
# TEACHERS                     float64
# FARMS_COUNT                  float64
# Special_ed_schl_new          float64
# Magnet_schl_new              float64
# Charter_Schl_new             float64
# Alternate_schl_new           float64
# Total_enroll_students        float64
# SCH_FTETEACH_TOT             float64
# SCH_FTETEACH_CERT            float64
# SCH_FTETEACH_NOTCERT         float64
# FTE_teachers_count           float64
# SalaryforTeachers            float64
# Total_SAT_ACT_students       float64
# SCH_IBENR_IND_new            float64
# Total_IB_students            float64
# SCH_APENR_IND_new            float64
# SCH_APCOURSES                float64
# SCH_APOTHENR_IND_new         float64
# Total_AP_other_students      float64
# Total_students_tookAP        float64
# Income_Poverty_ratio         float64
# IPR_SE                       float64
# ALL_RLA00NUMVALID_1718       float64
# ALL_RLA00PCTPROF_1718_new    float64
# dtype: object

# %%
master_reading_new.hist(figsize=(12,12))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7ffc26bddd00>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7ffc26b8ae20>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7ffc26c609a0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7ffc26df2160>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7ffc26e188e0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7ffc26e44100>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7ffc26e510d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7ffc26e798b0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7ffc26ed8760>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7ffc26f00ee0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7ffc26f346a0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7ffc26f60e20>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7ffc26f955e0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7ffc26fbed60>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7ffc27833520>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7ffc2785cca0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7ffc27893460>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7ffc278babe0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7ffc278f13a0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7ffc2791bb20>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7ffc279532e0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7ffc2797aa60>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7ffc279af220>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7ffc279d89a0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7ffc27a12160>]],
#       dtype=object)

# %%
corr = master_reading.corr()

# %%
plt.figure(figsize=(20,10))
sns.heatmap(corr, cmap="Greens",annot=True)

# %%
X = master_reading_new.iloc[:,0:20]  #independent columns
y = master_reading_new.iloc[:,-1]    #target column i.e price range
#get correlations of each features in dataset
corrmat = master_reading_new.corr()
top_corr_features = corrmat.index
plt.figure(figsize=(20,10))
#plot heat map
g=sns.heatmap(master_reading_new[top_corr_features].corr(),annot=True,cmap="RdYlGn")
