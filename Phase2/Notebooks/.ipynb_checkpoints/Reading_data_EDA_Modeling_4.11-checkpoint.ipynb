# %% [markdown]
# ### Phase 2: Conducting EDA and model construction using the master_reading.csv file that contains all necessary features and target variable

# %%
import sys
print(sys.base_prefix)
# Out:
# /opt/anaconda3

# %%
#pip install --user scikit-learn

# %%
#!{sys.executable} -m pip install xgboost

# %%
#!{sys.executable} -m pip install lightgbm

# %% [markdown]
# #### Importing all necessary libraries

# %%
import pandas
pandas.__version__
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import pandas as pd
from sklearn.model_selection import cross_val_score, RepeatedStratifiedKFold, GridSearchCV, learning_curve, cross_val_predict
from sklearn.linear_model import LinearRegression, LassoCV, Ridge, LassoLarsCV,ElasticNetCV
from sklearn.ensemble import RandomForestRegressor, AdaBoostRegressor, ExtraTreesRegressor, GradientBoostingRegressor

from sklearn.pipeline import Pipeline
import warnings
import xgboost as xgb
import lightgbm as lgb
from scipy.stats import skew
from scipy import stats
from scipy.stats.stats import pearsonr
from scipy.stats import norm
from collections import Counter
from sklearn.preprocessing import StandardScaler, Normalizer, RobustScaler
from sklearn.model_selection import train_test_split
warnings.filterwarnings('ignore')
# %matplotlib inline

# %%
cd /Users/dansa/Documents/GitHub/Phase1/Data/MASTER
# Out:
# C:\Users\dansa\Documents\GitHub\Phase1\Data\MASTER

# %% [markdown]
# #### Loading the data and reformatting the school id column

# %%
master_reading_new = pandas.read_csv("master_reading.csv")
master_reading_new['NCESSCH'] = master_reading_new['NCESSCH'].apply(lambda x: '{0:0>12}'.format(x))
master_reading_new.head()
# Out:
#   SCHOOL_YEAR_x ST_x                           NAME       NCESSCH LEVEL  \
# 0     2017-2018   AL        Albertville High School  010000500871  High
# 1     2017-2018   AL             Asbury High School  010000600872  High
# 2     2017-2018   AL            Douglas High School  010000600878  High
# 3     2017-2018   AL   Kate D Smith DAR High School  010000600883  High
# 4     2017-2018   AL  Brindlee Mountain High School  010000601585  High
#
#   SCH_TYPE_TEXT_x  SCH_TYPE_x TITLEI_STATUS         TITLEI_STATUS_TEXT  \
# 0  Regular School           1  SWELIGSWPROG  Title I schoolwide school
# 1  Regular School           1  SWELIGSWPROG  Title I schoolwide school
# 2  Regular School           1  SWELIGSWPROG  Title I schoolwide school
# 3  Regular School           1  SWELIGSWPROG  Title I schoolwide school
# 4  Regular School           1  SWELIGSWPROG  Title I schoolwide school
#
#    TEACHERS            ...              Total_IB_students  SCH_APENR_IND_new  \
# 0     77.00            ...                          -18.0                1.0
# 1     28.64            ...                          -18.0                1.0
# 2     30.87            ...                          -18.0                1.0
# 3     24.04            ...                          -18.0                1.0
# 4     31.26            ...                          -18.0                1.0
#
#    SCH_APCOURSES  SCH_APOTHENR_IND_new  Total_AP_other_students  \
# 0            8.0                   1.0                    179.0
# 1            3.0                   1.0                     33.0
# 2            6.0                   1.0                    185.0
# 3            6.0                   1.0                    116.0
# 4            5.0                   1.0                     76.0
#
#    Total_students_tookAP  Income_Poverty_ratio  IPR_SE  \
# 0                  286.0                 248.0    80.0
# 1                   46.0                 241.0   127.0
# 2                  244.0                 213.0    51.0
# 3                  205.0                 254.0    48.0
# 4                  102.0                 329.0   150.0
#
#    ALL_RLA00NUMVALID_1718  ALL_RLA00PCTPROF_1718_new
# 0                   337.0                       32.0
# 1                   327.0                       30.0
# 2                   130.0                       42.0
# 3                   106.0                       57.0
# 4                   338.0                       31.0
#
# [5 rows x 33 columns]

# %%
master_reading_new.shape
# Out:
# (14741, 33)

# %% [markdown]
# #### Inspecting the data file

# %%
master_reading_new.columns
# Out:
# Index(['SCHOOL_YEAR_x', 'ST_x', 'NAME', 'NCESSCH', 'LEVEL', 'SCH_TYPE_TEXT_x',
#        'SCH_TYPE_x', 'TITLEI_STATUS', 'TITLEI_STATUS_TEXT', 'TEACHERS',
#        'FARMS_COUNT', 'Special_ed_schl_new', 'Magnet_schl_new',
#        'Charter_Schl_new', 'Alternate_schl_new', 'Total_enroll_students',
#        'SCH_FTETEACH_TOT', 'SCH_FTETEACH_CERT', 'SCH_FTETEACH_NOTCERT',
#        'FTE_teachers_count', 'SalaryforTeachers', 'Total_SAT_ACT_students',
#        'SCH_IBENR_IND_new', 'Total_IB_students', 'SCH_APENR_IND_new',
#        'SCH_APCOURSES', 'SCH_APOTHENR_IND_new', 'Total_AP_other_students',
#        'Total_students_tookAP', 'Income_Poverty_ratio', 'IPR_SE',
#        'ALL_RLA00NUMVALID_1718', 'ALL_RLA00PCTPROF_1718_new'],
#       dtype='object')

# %% [markdown]
# Create a data frame with only the needed columns for further analysis

# %%
reading=pd.DataFrame(master_reading_new, columns=[ 'NCESSCH','SCH_TYPE_x', 
       'TITLEI_STATUS','TEACHERS', 'FARMS_COUNT', 'Total_enroll_students',
       'SCH_FTETEACH_TOT', 'SCH_FTETEACH_CERT', 'SCH_FTETEACH_NOTCERT',
       'FTE_teachers_count', 'SalaryforTeachers', 'Total_SAT_ACT_students',
       'SCH_IBENR_IND_new', 'Total_IB_students', 'SCH_APENR_IND_new',
       'SCH_APCOURSES', 'SCH_APOTHENR_IND_new', 'Total_AP_other_students',
       'Total_students_tookAP', 'Income_Poverty_ratio','ALL_RLA00PCTPROF_1718_new'])

# %%
reading.head()
# Out:
#         NCESSCH  SCH_TYPE_x TITLEI_STATUS  TEACHERS  FARMS_COUNT  \
# 0  010000500871           1  SWELIGSWPROG     77.00        832.0
# 1  010000600872           1  SWELIGSWPROG     28.64        450.0
# 2  010000600878           1  SWELIGSWPROG     30.87        429.0
# 3  010000600883           1  SWELIGSWPROG     24.04        211.0
# 4  010000601585           1  SWELIGSWPROG     31.26        415.0
#
#    Total_enroll_students  SCH_FTETEACH_TOT  SCH_FTETEACH_CERT  \
# 0                 1449.0             78.17              71.17
# 1                  547.0             32.00              31.00
# 2                  591.0             36.00              36.00
# 3                  452.0             29.00              29.00
# 4                  632.0             37.00              36.00
#
#    SCH_FTETEACH_NOTCERT  FTE_teachers_count            ...              \
# 0                   7.0               72.88            ...
# 1                   1.0               32.00            ...
# 2                   0.0               36.00            ...
# 3                   0.0               29.00            ...
# 4                   1.0               37.00            ...
#
#    Total_SAT_ACT_students  SCH_IBENR_IND_new  Total_IB_students  \
# 0                   363.0                0.0              -18.0
# 1                    61.0                0.0              -18.0
# 2                   142.0                0.0              -18.0
# 3                   103.0                0.0              -18.0
# 4                    76.0                0.0              -18.0
#
#    SCH_APENR_IND_new  SCH_APCOURSES  SCH_APOTHENR_IND_new  \
# 0                1.0            8.0                   1.0
# 1                1.0            3.0                   1.0
# 2                1.0            6.0                   1.0
# 3                1.0            6.0                   1.0
# 4                1.0            5.0                   1.0
#
#    Total_AP_other_students  Total_students_tookAP  Income_Poverty_ratio  \
# 0                    179.0                  286.0                 248.0
# 1                     33.0                   46.0                 241.0
# 2                    185.0                  244.0                 213.0
# 3                    116.0                  205.0                 254.0
# 4                     76.0                  102.0                 329.0
#
#    ALL_RLA00PCTPROF_1718_new
# 0                       32.0
# 1                       30.0
# 2                       42.0
# 3                       57.0
# 4                       31.0
#
# [5 rows x 21 columns]

# %%
reading.rename(columns={'NCESSCH':'School_ID', 'SCH_TYPE_x':'School_type','FARMS_COUNT':'No.FARMS_students',
                       'SCH_FTETEACH_TOT':'FTE_teachcount','SCH_FTETEACH_CERT':'Certified_FTE_teachers','SCH_FTETEACH_NOTCERT':
                       'Noncertified_FTE_teachers','Total_SAT_ACT_students':'Students_participate_SAT_ACT','SCH_IBENR_IND_new':'IB_Indicator','SCH_APENR_IND_new':'AP_Indicator',
                        'SCH_APCOURSES':'No.ofAP_courses_offer','SCH_APOTHENR_IND_new':'Students_enroll_inotherAP?','ALL_RLA00PCTPROF_1718_new':'Percent_Reading_Proficient'}, inplace=True)

# %%
reading.describe()
# Out:
#         School_type      TEACHERS  No.FARMS_students  Total_enroll_students  \
# count  14741.000000  14741.000000       14741.000000           14741.000000
# mean       1.205006     49.984221         385.008683             834.859372
# std        0.747609     41.432348         435.446580             766.594202
# min        1.000000      0.000000           0.000000               8.000000
# 25%        1.000000     18.300000          97.000000             249.000000
# 50%        1.000000     36.210000         223.000000             547.000000
# 75%        1.000000     73.950000         512.000000            1260.000000
# max        4.000000    330.360000        4329.000000            4996.000000
#
#        FTE_teachcount  Certified_FTE_teachers  Noncertified_FTE_teachers  \
# count    14741.000000            14741.000000               14741.000000
# mean        52.011098               50.613540                   1.395502
# std         42.698300               41.997454                   4.685170
# min          0.010000                0.000000                   0.000000
# 25%         19.240000               18.680000                   0.000000
# 50%         38.000000               37.000000                   0.000000
# 75%         76.610000               74.450000                   1.000000
# max        396.000000              382.470000                 157.000000
#
#        FTE_teachers_count  SalaryforTeachers  Students_participate_SAT_ACT  \
# count        14741.000000       1.474100e+04                  14741.000000
# mean            52.995974       2.964231e+06                    202.014857
# std            653.908828       2.851093e+06                    232.578840
# min              0.010000       5.039000e+01                      1.000000
# 25%             18.000000       9.408270e+05                     40.000000
# 50%             35.000000       1.945716e+06                    112.000000
# 75%             70.000000       4.262916e+06                    285.000000
# max          79297.760000       2.973278e+07                   2788.000000
#
#        IB_Indicator  Total_IB_students  AP_Indicator  No.ofAP_courses_offer  \
# count  14741.000000       14741.000000  14741.000000           14741.000000
# mean       0.052778          -6.996405      0.700834               5.097483
# std        0.229881          66.386937      0.457908              11.474930
# min       -6.000000         -18.000000      0.000000              -9.000000
# 25%        0.000000         -18.000000      0.000000              -9.000000
# 50%        0.000000         -18.000000      1.000000               5.000000
# 75%        0.000000         -18.000000      1.000000              13.000000
# max        1.000000        1335.000000      1.000000              82.000000
#
#        Students_enroll_inotherAP?  Total_AP_other_students  \
# count                14741.000000             14741.000000
# mean                    -2.034530               137.592429
# std                      4.555488               234.225189
# min                     -9.000000               -18.000000
# 25%                     -9.000000               -18.000000
# 50%                      1.000000                38.000000
# 75%                      1.000000               197.000000
# max                      1.000000              3173.000000
#
#        Total_students_tookAP  Income_Poverty_ratio  Percent_Reading_Proficient
# count           14741.000000          14741.000000                 14741.00000
# mean              122.271759            295.829930                    50.23282
# std               214.380343            140.947022                    23.42022
# min               -18.000000             48.000000                     1.00000
# 25%               -18.000000            205.000000                    33.00000
# 50%                31.000000            264.000000                    49.50000
# 75%               170.000000            345.000000                    67.00000
# max              3162.000000            979.000000                    99.00000

# %%
print(reading.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14741 entries, 0 to 14740
# Data columns (total 21 columns):
# School_ID                       14741 non-null object
# School_type                     14741 non-null int64
# TITLEI_STATUS                   14741 non-null object
# TEACHERS                        14741 non-null float64
# No.FARMS_students               14741 non-null float64
# Total_enroll_students           14741 non-null float64
# FTE_teachcount                  14741 non-null float64
# Certified_FTE_teachers          14741 non-null float64
# Noncertified_FTE_teachers       14741 non-null float64
# FTE_teachers_count              14741 non-null float64
# SalaryforTeachers               14741 non-null float64
# Students_participate_SAT_ACT    14741 non-null float64
# IB_Indicator                    14741 non-null float64
# Total_IB_students               14741 non-null float64
# AP_Indicator                    14741 non-null float64
# No.ofAP_courses_offer           14741 non-null float64
# Students_enroll_inotherAP?      14741 non-null float64
# Total_AP_other_students         14741 non-null float64
# Total_students_tookAP           14741 non-null float64
# Income_Poverty_ratio            14741 non-null float64
# Percent_Reading_Proficient      14741 non-null float64
# dtypes: float64(18), int64(1), object(2)
# memory usage: 2.4+ MB
# None

# %% [markdown]
# We have 14,741 entries and no null values in any column. There are 21 columns, but we can drop the school_id and we'll want to split off the Percent_Reading_Proficient.
# The object type features should be strings.
#
# Let's take a quick look at some of the data.

# %%
reading.hist(bins=50, figsize=(20,15))
plt.show()

# %% [markdown]
# We can see that some features have most of their instances at or near zero and relatively few instances at higher values, in some cases much higher. Other features cluster close to zero and have long tails. We also see the percent_reading_proficient is almost normally distributed.

# %%
#reading['TITLEI_STATUS'].value_counts()

# %%
sns.set_style('darkgrid')
_plt = sns.countplot(x='TITLEI_STATUS', data=reading)
_plt.set_title('School Title I status')
_plt.set_xticklabels(['Title I  schoolwide school','Not a Title I school','Title I schoolwide eligible- Title I targeted assistance program','Title I schoolwide eligible school-No program','Title I targeted assistance eligible school– No program','Title I targeted assistance school'])
_plt.set_xticklabels(_plt.get_xticklabels(), rotation=45, horizontalalignment='right')
plt.savefig('/Users/dansa/Documents/Title1_dist.png', dpi=300, bbox_inches='tight')
plt.show()

# %%
# Plot Histogram
sns.distplot(reading['Percent_Reading_Proficient'] , fit=norm);

# Get the fitted parameters used by the function
(mu, sigma) = norm.fit(reading['Percent_Reading_Proficient'])
print( '\n mu = {:.2f} and sigma = {:.2f}\n'.format(mu, sigma))
plt.legend(['Normal dist. ($\mu=$ {:.2f} and $\sigma=$ {:.2f} )'.format(mu, sigma)],
            loc='best')
plt.ylabel('Frequency')
plt.title('Proficiency distribution')

fig = plt.figure()
res = stats.probplot(reading['Percent_Reading_Proficient'], plot=plt)
plt.show()

print("Skewness: %f" % reading['Percent_Reading_Proficient'].skew())
print("Kurtosis: %f" % reading['Percent_Reading_Proficient'].kurt())
# Out:
#  mu = 50.23 and sigma = 23.42
# Skewness: -0.003097
# Kurtosis: -0.684094

# %%
sns.set_style('darkgrid')
Type_plt = sns.countplot(x='School_type', data=reading)
Type_plt.set_title('School_types')
Type_plt.set_xticklabels(Type_plt.get_xticklabels(), rotation=45, horizontalalignment='right')
Type_plt.set_xticklabels(["1-Regular School", "2-Special Education School", "3-Career and Technical School", "4-Alternative Education School"])
plt.savefig('/Users/dansa/Documents/Type_dist.png', dpi=300, bbox_inches='tight')
plt.show()

# %%
reading['School_type'].value_counts()
# Out:
# 1    13744
# 4      945
# 3       83
# 2       21
# Name: School_type, dtype: int64

# %% [markdown]
# ##### There are very few alternative, charter and magnet high schools in the dataset
#
# Given that the number of alt, charter, magnet and sped schools are so small in the dataset we might want to exclude that columns in our model tuning later

# %%
reading['Pct_certified_teachers']=(reading['Certified_FTE_teachers']/reading['FTE_teachcount']*100) # lets find the percent of certified teachers

# %%
reading['Pct_noncertified_teachers']=(reading['Noncertified_FTE_teachers']/reading['FTE_teachcount']*100) # lets find the percent of noncertified teachers

# %%
reading['Salary_perFTE_teacher'] = reading['SalaryforTeachers']/reading['FTE_teachers_count'] # Lets find the salary per FTE in each school

# %%
reading['IPR_estimate'] = reading['Income_Poverty_ratio'] #Income poverty ratio is reported as a percent

# %%
#reading['Percent_Reading_Proficient'] = reading['Percent_Reading_Proficient']/100

# %%
reading_clean=reading.drop(['School_ID','Certified_FTE_teachers', 'Noncertified_FTE_teachers','FTE_teachcount','FTE_teachers_count','SalaryforTeachers','Income_Poverty_ratio' ], axis=1)

# %%
reading_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14741 entries, 0 to 14740
# Data columns (total 18 columns):
# School_type                     14741 non-null int64
# TITLEI_STATUS                   14741 non-null object
# TEACHERS                        14741 non-null float64
# No.FARMS_students               14741 non-null float64
# Total_enroll_students           14741 non-null float64
# Students_participate_SAT_ACT    14741 non-null float64
# IB_Indicator                    14741 non-null float64
# Total_IB_students               14741 non-null float64
# AP_Indicator                    14741 non-null float64
# No.ofAP_courses_offer           14741 non-null float64
# Students_enroll_inotherAP?      14741 non-null float64
# Total_AP_other_students         14741 non-null float64
# Total_students_tookAP           14741 non-null float64
# Percent_Reading_Proficient      14741 non-null float64
# Pct_certified_teachers          14741 non-null float64
# Pct_noncertified_teachers       14741 non-null float64
# Salary_perFTE_teacher           14741 non-null float64
# IPR_estimate                    14741 non-null float64
# dtypes: float64(16), int64(1), object(1)
# memory usage: 2.0+ MB

# %%
reading_clean.dtypes
# Out:
# School_type                       int64
# TITLEI_STATUS                    object
# TEACHERS                        float64
# No.FARMS_students               float64
# Total_enroll_students           float64
# Students_participate_SAT_ACT    float64
# IB_Indicator                    float64
# Total_IB_students               float64
# AP_Indicator                    float64
# No.ofAP_courses_offer           float64
# Students_enroll_inotherAP?      float64
# Total_AP_other_students         float64
# Total_students_tookAP           float64
# Percent_Reading_Proficient      float64
# Pct_certified_teachers          float64
# Pct_noncertified_teachers       float64
# Salary_perFTE_teacher           float64
# IPR_estimate                    float64
# dtype: object

# %%
reading_clean.describe()
# Out:
#         School_type      TEACHERS  No.FARMS_students  Total_enroll_students  \
# count  14741.000000  14741.000000       14741.000000           14741.000000
# mean       1.205006     49.984221         385.008683             834.859372
# std        0.747609     41.432348         435.446580             766.594202
# min        1.000000      0.000000           0.000000               8.000000
# 25%        1.000000     18.300000          97.000000             249.000000
# 50%        1.000000     36.210000         223.000000             547.000000
# 75%        1.000000     73.950000         512.000000            1260.000000
# max        4.000000    330.360000        4329.000000            4996.000000
#
#        Students_participate_SAT_ACT  IB_Indicator  Total_IB_students  \
# count                  14741.000000  14741.000000       14741.000000
# mean                     202.014857      0.052778          -6.996405
# std                      232.578840      0.229881          66.386937
# min                        1.000000     -6.000000         -18.000000
# 25%                       40.000000      0.000000         -18.000000
# 50%                      112.000000      0.000000         -18.000000
# 75%                      285.000000      0.000000         -18.000000
# max                     2788.000000      1.000000        1335.000000
#
#        AP_Indicator  No.ofAP_courses_offer  Students_enroll_inotherAP?  \
# count  14741.000000           14741.000000                14741.000000
# mean       0.700834               5.097483                   -2.034530
# std        0.457908              11.474930                    4.555488
# min        0.000000              -9.000000                   -9.000000
# 25%        0.000000              -9.000000                   -9.000000
# 50%        1.000000               5.000000                    1.000000
# 75%        1.000000              13.000000                    1.000000
# max        1.000000              82.000000                    1.000000
#
#        Total_AP_other_students  Total_students_tookAP  \
# count             14741.000000           14741.000000
# mean                137.592429             122.271759
# std                 234.225189             214.380343
# min                 -18.000000             -18.000000
# 25%                 -18.000000             -18.000000
# 50%                  38.000000              31.000000
# 75%                 197.000000             170.000000
# max                3173.000000            3162.000000
#
#        Percent_Reading_Proficient  Pct_certified_teachers  \
# count                14741.000000            14741.000000
# mean                     0.502328               97.117307
# std                      0.234202                8.501036
# min                      0.010000                0.000000
# 25%                      0.330000               97.914349
# 50%                      0.495000              100.000000
# 75%                      0.670000              100.000000
# max                      0.990000              125.000000
#
#        Pct_noncertified_teachers  Salary_perFTE_teacher  IPR_estimate
# count               14741.000000           14741.000000  14741.000000
# mean                    0.028688           59496.178610      2.958299
# std                     0.084163           19391.091634      1.409470
# min                     0.000000               1.380548      0.480000
# 25%                     0.000000           47515.886314      2.050000
# 50%                     0.000000           55871.479309      2.640000
# 75%                     0.020833           67852.047185      3.450000
# max                     1.000000          477254.000000      9.790000

# %%
sns.heatmap(reading_clean.isnull(),yticklabels=False,cbar=True,cmap='viridis')

# %%
reading_clean.shape
# Out:
# (14793, 18)

# %% [markdown]
# ### 3. Looking for Correlations and Visualizing
# We should calculate data correlations and plot a scatter matrix.
#
# For training the ML models, we'll want to separate the Percent_Reading_Proficient from the rest of the data. But for investigating correlations, we'll want to include the target.

# %%
reading_clean=reading_clean[['School_type', 'TITLEI_STATUS', 'TEACHERS', 'No.FARMS_students',
       'Total_enroll_students', 'Students_participate_SAT_ACT', 'IB_Indicator',
       'Total_IB_students', 'AP_Indicator', 'No.ofAP_courses_offer',
       'Students_enroll_inotherAP?', 'Total_AP_other_students',
       'Total_students_tookAP',
       'Pct_certified_teachers', 'Pct_noncertified_teachers',
       'Salary_perFTE_teacher', 'IPR_estimate','Percent_Reading_Proficient']]

# %%
correlation_matrix = reading_clean.corr()

# %%
correlation_matrix['Percent_Reading_Proficient'].sort_values(ascending=False)
# Out:
# Percent_Reading_Proficient      1.000000
# IPR_estimate                    0.365394
# No.ofAP_courses_offer           0.277393
# Total_students_tookAP           0.263835
# Total_AP_other_students         0.231563
# Students_enroll_inotherAP?      0.204172
# AP_Indicator                    0.202322
# Students_participate_SAT_ACT    0.184785
# TEACHERS                        0.184153
# Salary_perFTE_teacher           0.177793
# Total_enroll_students           0.169084
# Pct_certified_teachers          0.091333
# IB_Indicator                    0.040580
# Total_IB_students               0.035890
# Pct_noncertified_teachers      -0.092175
# No.FARMS_students              -0.096545
# School_type                    -0.226007
# Name: Percent_Reading_Proficient, dtype: float64

# %% [markdown]
# It seems like a few features (IPR_estimate, No.ofAP_courses_offer, Total_students_tookAP) have a weak to moderate positive correlation to the target (Percent_Reading_Proficient), and a couple are somewhat negatively correlated (School_type).
#
# IPR_estimate is the Neighborhood Income Poverty Ratio.
# No.ofAP_courses_offer is the count of AP courses offered at the school.
# Total_students_tookAP is the number of students who took an AP course.
# School_type is refers to whether the school is a "1-Regular School, 2-Special Education School, 3-Career and Technical School and 4-Alternative Education School"
#
# We can look at a heatmap of the correlations of all numeric features to visualize which features are correlated.

# %%
# correlation matrix heatmap
plt.figure(figsize=(28,15))
corr_heatmap = sns.heatmap(correlation_matrix, annot=True, linewidths=0.2, center=0, cmap="RdYlGn")
corr_heatmap.set_title('Correlation Heatmap')
plt.savefig('/Users/dansa/Documents/corr_heatmap.png', dpi=300, bbox_inches='tight')

# %%
#test
corr_pairs = {}
feats = correlation_matrix.columns
for x in feats:
    for y in feats:
        if x != y and np.abs(correlation_matrix[x][y]) >= 0.7:  # which pairs are strongely correlated?
            if (y, x) not in corr_pairs.keys():
                corr_pairs[(x, y)] = correlation_matrix[x][y]

# %%
corr_pairs
# Out:
# {('TEACHERS', 'Total_enroll_students'): 0.9393684328066904,
#  ('TEACHERS', 'Students_participate_SAT_ACT'): 0.8092354431957515,
#  ('TEACHERS', 'No.ofAP_courses_offer'): 0.7389312014985094,
#  ('TEACHERS', 'Total_AP_other_students'): 0.7603038101612393,
#  ('TEACHERS', 'Total_students_tookAP'): 0.7398871166645457,
#  ('No.FARMS_students', 'Total_enroll_students'): 0.7593207902634703,
#  ('Total_enroll_students', 'Students_participate_SAT_ACT'): 0.8485992734549161,
#  ('Total_enroll_students', 'No.ofAP_courses_offer'): 0.7272821234335629,
#  ('Total_enroll_students', 'Total_AP_other_students'): 0.8121683434292307,
#  ('Total_enroll_students', 'Total_students_tookAP'): 0.7863545779575138,
#  ('Students_participate_SAT_ACT',
#   'Total_AP_other_students'): 0.7673171045352467,
#  ('Students_participate_SAT_ACT', 'Total_students_tookAP'): 0.7738798726238139,
#  ('AP_Indicator', 'No.ofAP_courses_offer'): 0.8023874699093486,
#  ('AP_Indicator', 'Students_enroll_inotherAP?'): 0.9990324434929398,
#  ('No.ofAP_courses_offer', 'Students_enroll_inotherAP?'): 0.8089118968874649,
#  ('No.ofAP_courses_offer', 'Total_AP_other_students'): 0.7513332389213118,
#  ('No.ofAP_courses_offer', 'Total_students_tookAP'): 0.734846404681833,
#  ('Total_AP_other_students', 'Total_students_tookAP'): 0.9477837105154745,
#  ('Pct_certified_teachers', 'Pct_noncertified_teachers'): -0.9890113186922548}

# %%
weaker_label = []
for pair in corr_pairs:
    if np.abs(correlation_matrix[pair[0]]['Percent_Reading_Proficient']) < np.abs(correlation_matrix[pair[1]]['Percent_Reading_Proficient']):
        weaker_label.append(pair[0])
    else:
        weaker_label.append(pair[1])

# %%
poss_redundant_feats = set(weaker_label)
poss_redundant_feats
# Out:
# {'AP_Indicator',
#  'No.FARMS_students',
#  'Pct_certified_teachers',
#  'Students_enroll_inotherAP?',
#  'Students_participate_SAT_ACT',
#  'TEACHERS',
#  'Total_AP_other_students',
#  'Total_enroll_students',
#  'Total_students_tookAP'}

# %%
cov_matrix = reading_clean.cov()
plt.figure(figsize=(28,15))
covar_heatmap = sns.heatmap(data=cov_matrix, cmap='coolwarm', linewidth=0.2) 
covar_heatmap.set_title('Covariance Heatmap')
plt.savefig('/Users/dansa/Documents/covar_heatmap.png', dpi=300, bbox_inches='tight')

# %%
attrs = ['IPR_estimate','No.ofAP_courses_offer','Total_students_tookAP','Percent_Reading_Proficient']

# %%
sns.set(style='ticks', color_codes=True)
_ = sns.pairplot(data=correlation_matrix[attrs], height=3, aspect=1, kind='scatter', plot_kws={'alpha':0.9})

# %%
#from pandas.plotting import scatter_matrix
#attributes = ["Percent_Reading_Proficient", "IPR_estimate", "No.ofAP_courses_offer","Total_students_tookAP","Total_AP_other_students"]
#scatter_matrix(reading_clean[attributes], figsize=(12, 8))

# %%
sns.jointplot(x="IPR_estimate", y="Percent_Reading_Proficient", data=reading_clean)

# %% [markdown]
# ### ML prep
# #### Separate labels
# Let's separate out the target from the predicting features.

# %%
from sklearn.model_selection import train_test_split
train, test = train_test_split(reading_clean, test_size=0.2, random_state=0)

# %%
df_X_train = train.drop(['Percent_Reading_Proficient'], axis=1)
df_y_train = train['Percent_Reading_Proficient'].copy()

df_X_test = test.drop(['Percent_Reading_Proficient'], axis=1)
df_y_test = test['Percent_Reading_Proficient'].copy()

# %%
df_X_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 11792 entries, 3420 to 2732
# Data columns (total 17 columns):
# School_type                     11792 non-null int64
# TITLEI_STATUS                   11792 non-null object
# TEACHERS                        11792 non-null float64
# No.FARMS_students               11792 non-null float64
# Total_enroll_students           11792 non-null float64
# Students_participate_SAT_ACT    11792 non-null float64
# IB_Indicator                    11792 non-null float64
# Total_IB_students               11792 non-null float64
# AP_Indicator                    11792 non-null float64
# No.ofAP_courses_offer           11792 non-null float64
# Students_enroll_inotherAP?      11792 non-null float64
# Total_AP_other_students         11792 non-null float64
# Total_students_tookAP           11792 non-null float64
# Pct_certified_teachers          11792 non-null float64
# Pct_noncertified_teachers       11792 non-null float64
# Salary_perFTE_teacher           11792 non-null float64
# IPR_estimate                    11792 non-null float64
# dtypes: float64(15), int64(1), object(1)
# memory usage: 1.6+ MB

# %% [markdown]
# #### Transform Categorical Features
# Since these categorical features don't appear to have an inherent ordering, let's try encoding them as one-hot vectors for better ML performance.

# %%
train_data_onehot = pd.get_dummies(df_X_train, columns=['TITLEI_STATUS'], prefix=['TITLEI_STATUS'])
train_data_onehot.head()

test_data_onehot = pd.get_dummies(df_X_test, columns=['TITLEI_STATUS'], prefix=['TITLEI_STATUS'])

# %%
train_data_onehot.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 11792 entries, 3420 to 2732
# Data columns (total 22 columns):
# School_type                     11792 non-null int64
# TEACHERS                        11792 non-null float64
# No.FARMS_students               11792 non-null float64
# Total_enroll_students           11792 non-null float64
# Students_participate_SAT_ACT    11792 non-null float64
# IB_Indicator                    11792 non-null float64
# Total_IB_students               11792 non-null float64
# AP_Indicator                    11792 non-null float64
# No.ofAP_courses_offer           11792 non-null float64
# Students_enroll_inotherAP?      11792 non-null float64
# Total_AP_other_students         11792 non-null float64
# Total_students_tookAP           11792 non-null float64
# Pct_certified_teachers          11792 non-null float64
# Pct_noncertified_teachers       11792 non-null float64
# Salary_perFTE_teacher           11792 non-null float64
# IPR_estimate                    11792 non-null float64
# TITLEI_STATUS_NOTTITLE1ELIG     11792 non-null uint8
# TITLEI_STATUS_SWELIGNOPROG      11792 non-null uint8
# TITLEI_STATUS_SWELIGSWPROG      11792 non-null uint8
# TITLEI_STATUS_SWELIGTGPROG      11792 non-null uint8
# TITLEI_STATUS_TGELGBNOPROG      11792 non-null uint8
# TITLEI_STATUS_TGELGBTGPROG      11792 non-null uint8
# dtypes: float64(15), int64(1), uint8(6)
# memory usage: 1.6 MB

# %% [markdown]
# #### Scale Features
# We can check out the statistics for each feature, do they need to be normalized?

# %%
train_data_onehot.describe()
# Out:
#         School_type      TEACHERS  No.FARMS_students  Total_enroll_students  \
# count  11792.000000  11792.000000       11792.000000           11792.000000
# mean       1.206157     49.794276         383.549271             831.246014
# std        0.749513     41.136573         434.035200             762.333353
# min        1.000000      0.000000           0.000000               8.000000
# 25%        1.000000     18.300000          97.000000             249.000000
# 50%        1.000000     36.100000         223.000000             548.000000
# 75%        1.000000     73.475000         511.000000            1250.250000
# max        4.000000    330.360000        4329.000000            4996.000000
#
#        Students_participate_SAT_ACT  IB_Indicator  Total_IB_students  \
# count                  11792.000000  11792.000000       11792.000000
# mean                     201.237449      0.052578          -7.073694
# std                      232.773608      0.231041          66.557475
# min                        1.000000     -6.000000         -18.000000
# 25%                       39.000000      0.000000         -18.000000
# 50%                      112.000000      0.000000         -18.000000
# 75%                      282.000000      0.000000         -18.000000
# max                     2788.000000      1.000000        1335.000000
#
#        AP_Indicator  No.ofAP_courses_offer  Students_enroll_inotherAP?  \
# count  11792.000000           11792.000000                11792.000000
# mean       0.699627               5.072592                   -2.046981
# std        0.458440              11.454015                    4.560508
# min        0.000000              -9.000000                   -9.000000
# 25%        0.000000              -9.000000                   -9.000000
# 50%        1.000000               5.000000                    1.000000
# 75%        1.000000              13.000000                    1.000000
# max        1.000000              37.000000                    1.000000
#
#                   ...              Pct_certified_teachers  \
# count             ...                        11792.000000
# mean              ...                           97.158943
# std               ...                            8.340582
# min               ...                            0.000000
# 25%               ...                           97.981104
# 50%               ...                          100.000000
# 75%               ...                          100.000000
# max               ...                          125.000000
#
#        Pct_noncertified_teachers  Salary_perFTE_teacher  IPR_estimate  \
# count               11792.000000           11792.000000  11792.000000
# mean                    0.028240           59506.324559      2.961529
# std                     0.082342           19525.810512      1.407930
# min                     0.000000            2675.263158      0.480000
# 25%                     0.000000           47424.825103      2.060000
# 50%                     0.000000           55875.195696      2.640000
# 75%                     0.020121           67874.978277      3.450000
# max                     1.000000          477254.000000      9.740000
#
#        TITLEI_STATUS_NOTTITLE1ELIG  TITLEI_STATUS_SWELIGNOPROG  \
# count                 11792.000000                11792.000000
# mean                      0.346082                    0.163161
# std                       0.475740                    0.369529
# min                       0.000000                    0.000000
# 25%                       0.000000                    0.000000
# 50%                       0.000000                    0.000000
# 75%                       1.000000                    0.000000
# max                       1.000000                    1.000000
#
#        TITLEI_STATUS_SWELIGSWPROG  TITLEI_STATUS_SWELIGTGPROG  \
# count                11792.000000                11792.000000
# mean                     0.278748                    0.014586
# std                      0.448402                    0.119894
# min                      0.000000                    0.000000
# 25%                      0.000000                    0.000000
# 50%                      0.000000                    0.000000
# 75%                      1.000000                    0.000000
# max                      1.000000                    1.000000
#
#        TITLEI_STATUS_TGELGBNOPROG  TITLEI_STATUS_TGELGBTGPROG
# count                11792.000000                11792.000000
# mean                     0.130851                    0.066571
# std                      0.337252                    0.249287
# min                      0.000000                    0.000000
# 25%                      0.000000                    0.000000
# 50%                      0.000000                    0.000000
# 75%                      0.000000                    0.000000
# max                      1.000000                    1.000000
#
# [8 rows x 22 columns]

# %% [markdown]
# We'll probably want to scale these features using normalization or standardization.

# %%
sc= StandardScaler()
train_scaler = sc.fit(train_data_onehot)
test_scaler = sc.fit(test_data_onehot)

# %%
train_data_standardized = train_scaler.transform(train_data_onehot)
test_data_standardized = test_scaler.transform(test_data_onehot)

# %%
print(train_data_standardized)
print(train_data_standardized.mean(axis=0))
# Out:
# [[-0.2708464   0.54140509  0.78494    ... -0.1244824  -0.38923427
#   -0.2754718 ]
#  [-0.2708464   0.79571425  1.37678168 ... -0.1244824  -0.38923427
#   -0.2754718 ]
#  [-0.2708464  -0.03930271 -0.48264429 ... -0.1244824   2.56914684
#   -0.2754718 ]
#  ...
#  [-0.2708464   0.08233362 -0.20599799 ... -0.1244824  -0.38923427
#   -0.2754718 ]
#  [-0.2708464  -0.98914624 -0.75022023 ... -0.1244824   2.56914684
#   -0.2754718 ]
#  [ 3.78360046 -0.88629544 -0.74795263 ... -0.1244824  -0.38923427
#   -0.2754718 ]]
# [ 0.00777075 -0.02229533 -0.01654228 -0.0230607  -0.01676637 -0.00443848
#  -0.00588042 -0.01324443 -0.01076555 -0.0137244  -0.01317632 -0.01000902
#   0.02283925 -0.02462564  0.00269154  0.01140495  0.00972242  0.00754315
#  -0.00450588 -0.0054922  -0.00212589 -0.01547334]

# %%
print(train_data_standardized.std(axis=0))
# Out:
# [1.01291105 0.96592462 0.9841733  0.97327583 1.0042772  1.02597436
#  1.01301236 1.00587184 0.99099212 1.00557779 0.99695998 0.99977461
#  0.91525146 0.90425573 1.03620565 0.99458442 1.00319787 1.00692823
#  0.99778923 0.97802516 0.99767792 0.97357728]

# %%
train_data_std = pd.DataFrame(train_data_standardized, columns=train_data_onehot.columns)
test_data_std = pd.DataFrame(test_data_standardized, columns=test_data_onehot.columns)

# %%
train_data_std.describe()
# Out:
#         School_type      TEACHERS  No.FARMS_students  Total_enroll_students  \
# count  11792.000000  11792.000000       11792.000000           11792.000000
# mean       0.007771     -0.022295          -0.016542              -0.023061
# std        1.012954      0.965966           0.984215               0.973317
# min       -0.270846     -1.191560          -0.886276              -1.074149
# 25%       -0.270846     -0.761841          -0.666319              -0.766449
# 50%       -0.270846     -0.343863          -0.380603              -0.384698
# 75%       -0.270846      0.533773           0.272464               0.511907
# max        3.783600      6.565926           8.930133               5.294333
#
#        Students_participate_SAT_ACT  IB_Indicator  Total_IB_students  \
# count                  11792.000000  11792.000000       11792.000000
# mean                      -0.016766     -0.004438          -0.005880
# std                        1.004320      1.026018           1.013055
# min                       -0.880706    -26.883042          -0.172187
# 25%                       -0.716752     -0.237930          -0.172187
# 50%                       -0.401788     -0.237930          -0.172187
# 75%                        0.331690     -0.237930          -0.172187
# max                       11.144021      4.202922          20.421501
#
#        AP_Indicator  No.ofAP_courses_offer  Students_enroll_inotherAP?  \
# count  11792.000000           11792.000000                11792.000000
# mean      -0.013244              -0.010766                   -0.013724
# std        1.005914               0.991034                    1.005620
# min       -1.548375              -1.228366                   -1.546908
# 25%       -1.548375              -1.228366                   -1.546908
# 50%        0.645838              -0.017046                    0.658154
# 75%        0.645838               0.675137                    0.658154
# max        0.645838               2.751685                    0.658154
#
#                   ...              Pct_certified_teachers  \
# count             ...                        11792.000000
# mean              ...                            0.022839
# std               ...                            0.915290
# min               ...                          -10.639323
# 25%               ...                            0.113063
# 50%               ...                            0.334615
# 75%               ...                            0.334615
# max               ...                            3.078100
#
#        Pct_noncertified_teachers  Salary_perFTE_teacher  IPR_estimate  \
# count               11792.000000           11792.000000  11792.000000
# mean                   -0.024626               0.002692      0.011405
# std                     0.904294               1.036250      0.994627
# min                    -0.334758              -3.013376     -1.741661
# 25%                    -0.334758              -0.638483     -0.625476
# 50%                    -0.334758              -0.190015     -0.215738
# 75%                    -0.113781               0.446822      0.356483
# max                    10.647405              22.172878      4.800028
#
#        TITLEI_STATUS_NOTTITLE1ELIG  TITLEI_STATUS_SWELIGNOPROG  \
# count                 11792.000000                11792.000000
# mean                      0.009722                    0.007543
# std                       1.003240                    1.006971
# min                      -0.720096                   -0.437074
# 25%                      -0.720096                   -0.437074
# 50%                      -0.720096                   -0.437074
# 75%                       1.388705                   -0.437074
# max                       1.388705                    2.287941
#
#        TITLEI_STATUS_SWELIGSWPROG  TITLEI_STATUS_SWELIGTGPROG  \
# count                11792.000000                11792.000000
# mean                    -0.004506                   -0.005492
# std                      0.997832                    0.978067
# min                     -0.624805                   -0.124482
# 25%                     -0.624805                   -0.124482
# 50%                     -0.624805                   -0.124482
# 75%                      1.600498                   -0.124482
# max                      1.600498                    8.033264
#
#        TITLEI_STATUS_TGELGBNOPROG  TITLEI_STATUS_TGELGBTGPROG
# count                11792.000000                11792.000000
# mean                    -0.002126                   -0.015473
# std                      0.997720                    0.973619
# min                     -0.389234                   -0.275472
# 25%                     -0.389234                   -0.275472
# 50%                     -0.389234                   -0.275472
# 75%                     -0.389234                   -0.275472
# max                      2.569147                    3.630136
#
# [8 rows x 22 columns]

# %% [markdown]
# That should work better, the standard deviation for each feature is 1 and the mean is ~0.

# %% [markdown]
# ### Using a multiple linear regression model

# %%
from sklearn.linear_model import LinearRegression
regressor = LinearRegression()
regressor.fit(train_data_std, df_y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None,
#          normalize=False)

# %%
y_pred = regressor.predict(test_data_std)

# %%
from termcolor import colored as cl

# %%
print(cl('R-Squared :', attrs = ['bold']), regressor.score(test_data_std, df_y_test))
# Out:
# R-Squared : 0.26184923132205995

# %%
# Method 2 Using Statsmodels
import statsmodels.api as sm
from scipy import stats

# %%
y = list(df_y_train)

# %%
X2 = sm.add_constant(train_data_std) 
# Define the model
est = sm.OLS(y, X2)
# Fit the model
est2 = est.fit()
print("summary()\n",est2.summary())
print("pvalues\n",est2.pvalues)
print("tvalues\n",est2.tvalues)
print("rsquared\n",est2.rsquared)
print("rsquared_adj\n",est2.rsquared_adj)
# Out:
# summary()
#                              OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.261
# Model:                            OLS   Adj. R-squared:                  0.260
# Method:                 Least Squares   F-statistic:                     197.8
# Date:                Sun, 11 Apr 2021   Prob (F-statistic):               0.00
# Time:                        20:17:02   Log-Likelihood:                 2167.2
# No. Observations:               11792   AIC:                            -4290.
# Df Residuals:                   11770   BIC:                            -4128.
# Df Model:                          21
# Covariance Type:            nonrobust
# ================================================================================================
#                                    coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------
# const                            0.5034      0.002    270.831      0.000       0.500       0.507
# School_type                     -0.0416      0.002    -20.980      0.000      -0.046      -0.038
# TEACHERS                         0.0068      0.006      1.149      0.251      -0.005       0.018
# No.FARMS_students               -0.0570      0.004    -14.395      0.000      -0.065      -0.049
# Total_enroll_students            0.0275      0.008      3.407      0.001       0.012       0.043
# Students_participate_SAT_ACT    -0.0100      0.004     -2.709      0.007      -0.017      -0.003
# IB_Indicator                     0.0024      0.002      0.955      0.340      -0.002       0.007
# Total_IB_students                0.0010      0.003      0.403      0.687      -0.004       0.006
# AP_Indicator                    -0.0625      0.043     -1.446      0.148      -0.147       0.022
# No.ofAP_courses_offer            0.0234      0.005      4.481      0.000       0.013       0.034
# Students_enroll_inotherAP?       0.0668      0.044      1.523      0.128      -0.019       0.153
# Total_AP_other_students         -0.0378      0.006     -5.975      0.000      -0.050      -0.025
# Total_students_tookAP            0.0532      0.006      8.777      0.000       0.041       0.065
# Pct_certified_teachers          -0.0015      0.012     -0.124      0.901      -0.025       0.022
# Pct_noncertified_teachers       -0.0040      0.012     -0.327      0.744      -0.028       0.020
# Salary_perFTE_teacher            0.0236      0.002     12.058      0.000       0.020       0.027
# IPR_estimate                     0.0337      0.003     13.312      0.000       0.029       0.039
# TITLEI_STATUS_NOTTITLE1ELIG      0.0208      0.001     14.919      0.000       0.018       0.024
# TITLEI_STATUS_SWELIGNOPROG       0.0027      0.002      1.752      0.080      -0.000       0.006
# TITLEI_STATUS_SWELIGSWPROG      -0.0258      0.002    -16.544      0.000      -0.029      -0.023
# TITLEI_STATUS_SWELIGTGPROG       0.0108      0.002      5.789      0.000       0.007       0.014
# TITLEI_STATUS_TGELGBNOPROG      -0.0034      0.002     -2.093      0.036      -0.007      -0.000
# TITLEI_STATUS_TGELGBTGPROG       0.0021      0.002      1.144      0.253      -0.001       0.006
# ==============================================================================
# Omnibus:                       99.140   Durbin-Watson:                   1.984
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              115.101
# Skew:                          -0.169   Prob(JB):                     1.01e-25
# Kurtosis:                       3.346   Cond. No.                     3.14e+15
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 7.81e-27. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
# pvalues
#  const                           0.000000e+00
# School_type                     5.641365e-96
# TEACHERS                        2.506167e-01
# No.FARMS_students               1.385896e-46
# Total_enroll_students           6.599914e-04
# Students_participate_SAT_ACT    6.761370e-03
# IB_Indicator                    3.397189e-01
# Total_IB_students               6.868019e-01
# AP_Indicator                    1.482935e-01
# No.ofAP_courses_offer           7.489214e-06
# Students_enroll_inotherAP?      1.278816e-01
# Total_AP_other_students         2.361157e-09
# Total_students_tookAP           1.914743e-18
# Pct_certified_teachers          9.010459e-01
# Pct_noncertified_teachers       7.439125e-01
# Salary_perFTE_teacher           2.779078e-33
# IPR_estimate                    3.865926e-40
# TITLEI_STATUS_NOTTITLE1ELIG     7.054374e-50
# TITLEI_STATUS_SWELIGNOPROG      7.974644e-02
# TITLEI_STATUS_SWELIGSWPROG      8.643444e-61
# TITLEI_STATUS_SWELIGTGPROG      7.255433e-09
# TITLEI_STATUS_TGELGBNOPROG      3.636874e-02
# TITLEI_STATUS_TGELGBTGPROG      2.526768e-01
# dtype: float64
# tvalues
#  const                           270.831197
# School_type                     -20.979995
# TEACHERS                          1.148909
# No.FARMS_students               -14.394809
# Total_enroll_students             3.406593
# Students_participate_SAT_ACT     -2.708854
# IB_Indicator                      0.954760
# Total_IB_students                 0.403209
# AP_Indicator                     -1.445680
# No.ofAP_courses_offer             4.481294
# Students_enroll_inotherAP?        1.522616
# Total_AP_other_students          -5.975435
# Total_students_tookAP             8.776696
# Pct_certified_teachers           -0.124343
# Pct_noncertified_teachers        -0.326684
# Salary_perFTE_teacher            12.057558
# IPR_estimate                     13.311572
# TITLEI_STATUS_NOTTITLE1ELIG      14.919203
# TITLEI_STATUS_SWELIGNOPROG        1.752311
# TITLEI_STATUS_SWELIGSWPROG      -16.543502
# TITLEI_STATUS_SWELIGTGPROG        5.789140
# TITLEI_STATUS_TGELGBNOPROG       -2.093020
# TITLEI_STATUS_TGELGBTGPROG        1.143928
# dtype: float64
# rsquared
#  0.26087286104692897
# rsquared_adj
#  0.25955411254072547

# %%
sns.distplot(y_pred, hist = False, color = 'r', label = 'Predicted Values')
sns.distplot(df_y_test, hist = False, color = 'b', label = 'Actual Values')
plt.title('Actual vs Predicted Values', fontsize = 16)
plt.xlabel('Values', fontsize = 12)
plt.ylabel('Frequency', fontsize = 12)
plt.legend(loc = 'upper left', fontsize = 13)
plt.savefig('ap.png')

# %%
df = pandas.DataFrame({'Actual':  df_y_test, 'Predicted': y_pred})
df
# Out:
#        Actual  Predicted
# 12723   0.410   0.478843
# 8209    0.620   0.607696
# 12581   0.630   0.699206
# 9413    0.510   0.522010
# 1191    0.770   0.568467
# 1392    0.300   0.250416
# 6487    0.370   0.515366
# 654     0.370   0.478735
# 6848    0.745   0.505969
# 14112   0.520   0.561880
# 5069    0.520   0.455438
# 7873    0.520   0.497838
# 3675    0.600   0.526754
# 10406   0.920   0.538224
# 5682    0.720   0.468234
# 13404   0.390   0.475503
# 8141    0.890   0.627073
# 11252   0.920   0.477717
# 5214    0.200   0.473991
# 4024    0.420   0.578330
# 11064   0.670   0.591008
# 2819    0.530   0.591116
# 278     0.280   0.596592
# 10452   0.800   0.659710
# 8113    0.280   0.426294
# 11329   0.950   0.465852
# 6718    0.600   0.506230
# 6713    0.470   0.478038
# 14137   0.270   0.475447
# 7814    0.490   0.418340
# ...       ...        ...
# 4115    0.300   0.518955
# 11600   0.540   0.308677
# 9998    0.100   0.409532
# 5991    0.200   0.309612
# 7767    0.200   0.379413
# 5897    0.270   0.415944
# 2472    0.720   0.697868
# 10435   0.760   0.631017
# 7711    0.800   0.586175
# 11119   0.500   0.754650
# 4880    0.495   0.426040
# 11577   0.720   0.470388
# 338     0.600   0.594558
# 5592    0.370   0.353589
# 13590   0.890   0.528950
# 3750    0.220   0.565541
# 2946    0.220   0.208095
# 10810   0.300   0.511995
# 7070    0.170   0.351775
# 2052    0.075   0.307866
# 8522    0.540   0.664689
# 6875    0.520   0.418721
# 4860    0.770   0.567075
# 11540   0.245   0.360916
# 2943    0.430   0.523569
# 9575    0.630   0.643834
# 4643    0.570   0.536980
# 7022    0.150   0.369551
# 12377   0.230   0.489839
# 9541    0.495   0.465420
#
# [2949 rows x 2 columns]

# %%
from sklearn import metrics
print('Mean Absolute Error:', metrics.mean_absolute_error( df_y_test, y_pred))
print('Mean Squared Error:', metrics.mean_squared_error( df_y_test, y_pred))
print('Root Mean Squared Error:', np.sqrt(metrics.mean_squared_error( df_y_test, y_pred)))
# Out:
# Mean Absolute Error: 0.158568004135484
# Mean Squared Error: 0.04044545455221449
# Root Mean Squared Error: 0.20111055306028694
